# %%
from transformers import DESeq2RatioNormalizer, FeatureSelection

from sklearn.model_selection import StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    cohen_kappa_score,
    matthews_corrcoef
)
from sklearn.model_selection import ParameterGrid
from sklearn.base import clone

from joblib import Parallel, delayed
import itertools
import numpy as np
import pandas as pd

# Classifiers
from sklearn.svm import SVC
from xgboost import XGBClassifier

# %%
from train_test import load_data, filter_data, encode_labels, conditional_f1
X, y, study_labels = load_data("/home/jeppe/Documents/Leukem.ai/data")
X, y, study_labels = filter_data(X, y, study_labels, min_n = 20)
y, label_mapping = encode_labels(y)
# Out:
#   studies_series: 2974
#   X_df: (60660, 2974)
#   y_series: 2974
#   Studies: 2974
#   X shape: (2974, 60660)
#   y: 2974
#   Studies: 1914
#   X shape: (1914, 60660)
#   y: 1914

# %%
# CV setup


model_type = "svm"
if model_type == "svm":
    model = SVC
    param_grid = {
    'n_genes': [1000, 2000, 3000],
    'C': [10, 100, 1000],
    'gamma': ['auto', 0.001, 0.01],
    'kernel': ['rbf'],
    'class_weight': ["balanced", None],
    'probability': [True]
    }
elif model_type == "xgboost":
    from classifiers import WeightedXGBClassifier
    model = WeightedXGBClassifier
    param_grid = {
    'n_genes': [1000],
    'class_weight': [True, False],
    'max_depth': [2,5]
    }
else:
    ValueError("model_type should be 'svm' or 'xgboost'")

param_grid = {
    'n_genes': [1000],
    'C': [10],
    'gamma': ['auto', 0.001],
    'kernel': ['rbf'],
    'class_weight': ["balanced"],
    'probability': [True]
}


pipe = Pipeline([
    ('DEseq2', transformers.DESeq2RatioNormalizer()),
    ('feature_selection', transformers.FeatureSelection()),
    ('scaler', StandardScaler())
])

# %%
studies_as_folds = [
        "BEATAML1.0-COHORT",
        "AAML0531",
        "AAML1031",
        "TCGA-LAML",
        "LEUCEGENE"
    ]

multi_type = "standard"
n_jobs = 12

import warnings
warnings.filterwarnings('always')


# Function to evaluate one inner fold + hyperparam combo



#for multi_type in ["standard", "OvO", "OvR"]:
#    df_parallel_results = run_inner_cv(X, y, study_labels, model, param_grid, n_jobs, multi_type = multi_type, k_out = 2, k_in = 2)

# %%
y_val_ij = [1,1,1,1, 1]
preds = [1,1,1,1, 1]
print(conditional_f1(y_val_ij, preds))
print(cohen_kappa_score(y_val_ij, preds))
print(matthews_corrcoef(y_val_ij, preds))
# Out:
# 1.0
# nan
# 0.0
# /home/jeppe/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(
# /home/jeppe/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:758: RuntimeWarning: invalid value encountered in scalar divide
#   k = np.sum(w_mat * confusion) / np.sum(w_mat * expected)
# /home/jeppe/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
def process_cv_results(df, param_grid, label_mapping, score_col):
    #  Extract param names and expand 'params'
    param_names = list(param_grid.keys())
    params_df = df['params'].apply(pd.Series)

    # Normalize None values for groupby
    for col in param_names:
        if col in params_df.columns:
            params_df[col] = params_df[col].apply(lambda x: 'none' if x is None else x)

    #Combine expanded params with original DataFrame
    df_with_params = pd.concat([df.drop(columns=['params']), params_df], axis=1)

    # Determine group-by strategy based on evaluation type
    if 'class' in df_with_params.columns:
        # OvR
        group_cols = param_names + ['class']
        summary = df_with_params.groupby(group_cols)[score_col].mean().reset_index()
        best = summary.loc[summary.groupby('class')[score_col].idxmax()].reset_index(drop=True)

    elif 'class_0' in df_with_params.columns and 'class_1' in df_with_params.columns:
        # OvO
        group_cols = param_names + ['class_0', 'class_1']
        summary = df_with_params.groupby(group_cols)[score_col].mean().reset_index()
        best = summary.loc[summary.groupby(['class_0', 'class_1'])[score_col].idxmax()].reset_index(drop=True)

    else:
        # Standard multiclass
        group_cols = param_names
        summary = df_with_params.groupby(group_cols)[score_col].mean().reset_index()
        best = summary.loc[[summary[score_col].idxmax()]].reset_index(drop=True)

    int_to_label = {v: k for k, v in label_mapping.items()}
    if 'class' in best.columns:
        # OvR case
        best['class_label'] = best['class'].map(int_to_label)
        return best

    elif 'class_0' in best.columns and 'class_1' in best.columns:
        # OvO case
        best['class_0_label'] = best['class_0'].map(int_to_label)
        best['class_1_label'] = best['class_1'].map(int_to_label)
        return best

    else:
        return best

best_per_class_df = process_cv_results(
    df_parallel_results,
    param_grid=param_grid,
    label_mapping = label_mapping,
    score_col = "kappa"
)
best_per_class_df["kappa"].mean()
# Out:
# np.float64(0.6709831404600013)

# %%
import warnings
warnings.filterwarnings('ignore')



for multi_type in ["OvO"]:
    print(multi_type)
    df_parallel_results_study_as_fold = run_inner_cv_loso(X, y, study_labels, model, param_grid, n_jobs=12, multi_type=multi_type)
df_parallel_results_study_as_fold
# Out:
# OvO
#
# --- Outer Loop: Holding out Study 'BEATAML1.0-COHORT' for Testing ---
# Outer training set contains studies: ['AAML0531', 'AAML1031', 'LEUCEGENE', 'TCGA-LAML']
#   Inner Loop: Validating on Study 'AAML0531'
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '1'
# classes '0' and '3'
# classes '0' and '2'
# classes '0' and '4'
# classes '0' and '3'
# classes '0' and '5'
# classes '0' and '4'
# classes '0' and '6'
# classes '0' and '7'
# classes '0' and '5'
# classes '0' and '8'
# classes '0' and '6'
# classes '0' and '9'
# classes '0' and '7'
# classes '0' and '11'
# classes '0' and '12'
# classes '0' and '13'
# classes '0' and '8'
# classes '0' and '14'
# classes '0' and '16'
# classes '1' and '2'
# classes '1' and '3'
# classes '0' and '9'
# classes '1' and '4'
# classes '1' and '5'
# classes '0' and '11'
# classes '1' and '6'
# classes '1' and '7'
# classes '1' and '8'
# classes '0' and '12'
# classes '1' and '9'
# classes '0' and '13'
# classes '1' and '11'
# classes '1' and '12'
# classes '0' and '14'
# classes '1' and '13'
# classes '1' and '14'
# classes '0' and '16'
# classes '1' and '16'
# classes '1' and '2'
# classes '2' and '3'
# classes '2' and '4'
# classes '1' and '3'
# classes '2' and '5'
# classes '2' and '6'
# classes '1' and '4'
# classes '2' and '7'
# classes '2' and '8'
# classes '2' and '9'
# classes '2' and '11'
# classes '2' and '12'
# classes '1' and '5'
# classes '2' and '13'
# classes '2' and '14'
# classes '1' and '6'
# classes '2' and '16'
# classes '3' and '4'
# classes '1' and '7'
# classes '3' and '5'
# classes '1' and '8'
# classes '3' and '6'
# classes '3' and '7'
# classes '1' and '9'
# classes '1' and '11'
# classes '3' and '8'
# classes '1' and '12'
# classes '3' and '9'
# classes '1' and '13'
# classes '3' and '11'
# classes '1' and '14'
# classes '3' and '12'
# classes '1' and '16'
# classes '3' and '13'
# classes '2' and '3'
# classes '3' and '14'
# classes '2' and '4'
# classes '3' and '16'
# classes '2' and '5'
# classes '4' and '5'
# classes '2' and '6'
# classes '4' and '6'
# classes '2' and '7'
# classes '4' and '7'
# classes '4' and '8'
# classes '2' and '8'
# classes '4' and '9'
# classes '2' and '9'
# classes '4' and '11'
# classes '4' and '12'
# classes '2' and '11'
# classes '4' and '13'
# classes '2' and '12'
# classes '4' and '14'
# classes '2' and '13'
# classes '4' and '16'
# classes '2' and '14'
# classes '2' and '16'
# classes '5' and '6'
# classes '3' and '4'
# classes '5' and '7'
# classes '5' and '8'
# classes '3' and '5'
# classes '3' and '6'
# classes '5' and '9'
# classes '3' and '7'
# classes '5' and '11'
# classes '5' and '12'
# classes '3' and '8'
# classes '5' and '13'
# classes '5' and '14'
# classes '3' and '9'
# classes '5' and '16'
# classes '3' and '11'
# classes '6' and '7'
# classes '3' and '12'
# classes '6' and '8'
# classes '3' and '13'
# classes '6' and '9'
# classes '3' and '14'
# classes '6' and '11'
# classes '3' and '16'
# classes '6' and '12'
# classes '6' and '13'
# classes '4' and '5'
# classes '6' and '14'
# classes '4' and '6'
# classes '6' and '16'
# classes '4' and '7'
# classes '7' and '8'
# classes '4' and '8'
# classes '7' and '9'
# classes '4' and '9'
# classes '7' and '11'
# classes '4' and '11'
# classes '7' and '12'
# classes '4' and '12'
# classes '7' and '13'
# classes '4' and '13'
# classes '7' and '14'
# classes '4' and '14'
# classes '7' and '16'
# classes '4' and '16'
# classes '8' and '9'
# classes '8' and '11'
# classes '5' and '6'
# classes '8' and '12'
# classes '5' and '7'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '5' and '8'
# classes '9' and '11'
# classes '9' and '12'
# classes '9' and '13'
# classes '5' and '9'
# classes '9' and '14'
# classes '9' and '16'
# classes '5' and '11'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '14'
# classes '5' and '12'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '5' and '13'
# classes '12' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '5' and '14'
# classes '14' and '16'
# classes '5' and '16'
# classes '6' and '7'
# classes '6' and '8'
# classes '6' and '9'
# classes '6' and '11'
# classes '6' and '12'
# classes '6' and '13'
# classes '6' and '14'
# classes '6' and '16'
# classes '7' and '8'
# classes '7' and '9'
# classes '7' and '11'
# classes '7' and '12'
# classes '7' and '13'
# classes '7' and '14'
# classes '7' and '16'
# classes '8' and '9'
# classes '8' and '11'
# classes '8' and '12'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '11'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:   16.5s finished
#   Inner Loop: Validating on Study 'AAML1031'
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '3'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '4'
# classes '0' and '7'
# classes '0' and '7'
# classes '0' and '8'
# classes '0' and '8'
# classes '0' and '9'
# classes '0' and '11'
# classes '0' and '9'
# classes '0' and '12'
# classes '0' and '11'
# classes '0' and '13'
# classes '0' and '12'
# classes '0' and '16'
# classes '0' and '13'
# classes '3' and '4'
# classes '0' and '16'
# classes '3' and '7'
# classes '3' and '8'
# classes '3' and '4'
# classes '3' and '9'
# classes '3' and '7'
# classes '3' and '11'
# classes '3' and '12'
# classes '3' and '8'
# classes '3' and '13'
# classes '3' and '9'
# classes '3' and '16'
# classes '4' and '7'
# classes '3' and '11'
# classes '4' and '8'
# classes '4' and '9'
# classes '3' and '12'
# classes '4' and '11'
# classes '4' and '12'
# classes '3' and '13'
# classes '4' and '13'
# classes '4' and '16'
# classes '3' and '16'
# classes '4' and '7'
# classes '7' and '8'
# classes '4' and '8'
# classes '7' and '9'
# classes '4' and '9'
# classes '7' and '11'
# classes '4' and '11'
# classes '7' and '12'
# classes '4' and '12'
# classes '7' and '13'
# classes '4' and '13'
# classes '7' and '16'
# classes '4' and '16'
# classes '8' and '9'
# classes '7' and '8'
# classes '8' and '11'
# classes '7' and '9'
# classes '8' and '12'
# classes '7' and '11'
# classes '7' and '12'
# classes '8' and '13'
# classes '7' and '13'
# classes '7' and '16'
# classes '8' and '16'
# classes '9' and '11'
# classes '8' and '9'
# classes '9' and '12'
# classes '9' and '13'
# classes '8' and '11'
# classes '9' and '16'
# classes '8' and '12'
# classes '11' and '12'
# classes '11' and '13'
# classes '8' and '13'
# classes '11' and '16'
# classes '12' and '13'
# classes '8' and '16'
# classes '12' and '16'
# classes '9' and '11'
# classes '13' and '16'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '16'
# classes '13' and '16'
#   Inner Loop: Validating on Study 'LEUCEGENE'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:    9.1s finished
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '1'
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '2'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '3'
# classes '0' and '5'
# classes '0' and '4'
# classes '0' and '6'
# classes '0' and '7'
# classes '0' and '5'
# classes '0' and '6'
# classes '0' and '7'
# classes '0' and '8'
# classes '0' and '9'
# classes '0' and '10'
# classes '0' and '11'
# classes '0' and '8'
# classes '0' and '12'
# classes '0' and '13'
# classes '0' and '14'
# classes '0' and '9'
# classes '0' and '16'
# classes '1' and '2'
# classes '0' and '10'
# classes '1' and '3'
# classes '1' and '4'
# classes '1' and '5'
# classes '0' and '11'
# classes '1' and '6'
# classes '1' and '7'
# classes '1' and '8'
# classes '0' and '12'
# classes '1' and '9'
# classes '1' and '10'
# classes '1' and '11'
# classes '1' and '12'
# classes '1' and '13'
# classes '0' and '13'
# classes '1' and '14'
# classes '1' and '16'
# classes '0' and '14'
# classes '2' and '3'
# classes '2' and '4'
# classes '2' and '5'
# classes '2' and '6'
# classes '2' and '7'
# classes '0' and '16'
# classes '2' and '8'
# classes '1' and '2'
# classes '2' and '9'
# classes '2' and '10'
# classes '2' and '11'
# classes '1' and '3'
# classes '2' and '12'
# classes '1' and '4'
# classes '2' and '13'
# classes '2' and '14'
# classes '1' and '5'
# classes '2' and '16'
# classes '1' and '6'
# classes '3' and '4'
# classes '1' and '7'
# classes '3' and '5'
# classes '1' and '8'
# classes '3' and '6'
# classes '1' and '9'
# classes '3' and '7'
# classes '1' and '10'
# classes '1' and '11'
# classes '1' and '12'
# classes '1' and '13'
# classes '3' and '8'
# classes '1' and '14'
# classes '1' and '16'
# classes '3' and '9'
# classes '3' and '10'
# classes '2' and '3'
# classes '2' and '4'
# classes '3' and '11'
# classes '2' and '5'
# classes '2' and '6'
# classes '3' and '12'
# classes '2' and '7'
# classes '3' and '13'
# classes '2' and '8'
# classes '3' and '14'
# classes '2' and '9'
# classes '2' and '10'
# classes '3' and '16'
# classes '2' and '11'
# classes '4' and '5'
# classes '2' and '12'
# classes '4' and '6'
# classes '2' and '13'
# classes '4' and '7'
# classes '2' and '14'
# classes '4' and '8'
# classes '2' and '16'
# classes '4' and '9'
# classes '4' and '10'
# classes '3' and '4'
# classes '4' and '11'
# classes '4' and '12'
# classes '4' and '13'
# classes '4' and '14'
# classes '4' and '16'
# classes '3' and '5'
# classes '5' and '6'
# classes '3' and '6'
# classes '5' and '7'
# classes '3' and '7'
# classes '5' and '8'
# classes '5' and '9'
# classes '5' and '10'
# classes '3' and '8'
# classes '5' and '11'
# classes '5' and '12'
# classes '5' and '13'
# classes '3' and '9'
# classes '5' and '14'
# classes '3' and '10'
# classes '5' and '16'
# classes '6' and '7'
# classes '3' and '11'
# classes '6' and '8'
# classes '3' and '12'
# classes '6' and '9'
# classes '6' and '10'
# classes '6' and '11'
# classes '3' and '13'
# classes '6' and '12'
# classes '6' and '13'
# classes '6' and '14'
# classes '3' and '14'
# classes '6' and '16'
# classes '3' and '16'
# classes '7' and '8'
# classes '7' and '9'
# classes '4' and '5'
# classes '4' and '6'
# classes '7' and '10'
# classes '4' and '7'
# classes '7' and '11'
# classes '7' and '12'
# classes '4' and '8'
# classes '7' and '13'
# classes '7' and '14'
# classes '4' and '9'
# classes '7' and '16'
# classes '4' and '10'
# classes '4' and '11'
# classes '4' and '12'
# classes '4' and '13'
# classes '8' and '9'
# classes '4' and '14'
# classes '8' and '10'
# classes '4' and '16'
# classes '5' and '6'
# classes '8' and '11'
# classes '8' and '12'
# classes '5' and '7'
# classes '8' and '13'
# classes '8' and '14'
# classes '5' and '8'
# classes '8' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '5' and '9'
# classes '5' and '10'
# classes '9' and '12'
# classes '5' and '11'
# classes '9' and '13'
# classes '5' and '12'
# classes '9' and '14'
# classes '5' and '13'
# classes '9' and '16'
# classes '10' and '11'
# classes '5' and '14'
# classes '10' and '12'
# classes '10' and '13'
# classes '10' and '14'
# classes '5' and '16'
# classes '10' and '16'
# classes '6' and '7'
# classes '11' and '12'
# classes '11' and '13'
# classes '6' and '8'
# classes '11' and '14'
# classes '11' and '16'
# classes '6' and '9'
# classes '6' and '10'
# classes '12' and '13'
# classes '12' and '14'
# classes '6' and '11'
# classes '6' and '12'
# classes '12' and '16'
# classes '6' and '13'
# classes '13' and '14'
# classes '6' and '14'
# classes '13' and '16'
# classes '6' and '16'
# classes '14' and '16'
# classes '7' and '8'
# classes '7' and '9'
# classes '7' and '10'
# classes '7' and '11'
# classes '7' and '12'
# classes '7' and '13'
# classes '7' and '14'
# classes '7' and '16'
# classes '8' and '9'
# classes '8' and '10'
# classes '8' and '11'
# classes '8' and '12'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '12'
# classes '10' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:   13.6s finished
#   Inner Loop: Validating on Study 'TCGA-LAML'
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '1'
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '2'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '5'
# classes '0' and '6'
# classes '0' and '5'
# classes '0' and '8'
# classes '0' and '6'
# classes '0' and '9'
# classes '0' and '10'
# classes '0' and '11'
# classes '0' and '8'
# classes '0' and '12'
# classes '0' and '13'
# classes '0' and '14'
# classes '0' and '16'
# classes '0' and '9'
# classes '1' and '2'
# classes '0' and '10'
# classes '1' and '3'
# classes '1' and '4'
# classes '1' and '5'
# classes '0' and '11'
# classes '1' and '6'
# classes '1' and '8'
# classes '0' and '12'
# classes '1' and '9'
# classes '1' and '10'
# classes '0' and '13'
# classes '1' and '11'
# classes '1' and '12'
# classes '1' and '13'
# classes '0' and '14'
# classes '1' and '14'
# classes '1' and '16'
# classes '2' and '3'
# classes '2' and '4'
# classes '0' and '16'
# classes '2' and '5'
# classes '2' and '6'
# classes '1' and '2'
# classes '2' and '8'
# classes '2' and '9'
# classes '2' and '10'
# classes '1' and '3'
# classes '2' and '11'
# classes '1' and '4'
# classes '2' and '12'
# classes '2' and '13'
# classes '2' and '14'
# classes '2' and '16'
# classes '3' and '4'
# classes '1' and '5'
# classes '1' and '6'
# classes '3' and '5'
# classes '3' and '6'
# classes '1' and '8'
# classes '1' and '9'
# classes '3' and '8'
# classes '1' and '10'
# classes '1' and '11'
# classes '3' and '9'
# classes '1' and '12'
# classes '3' and '10'
# classes '1' and '13'
# classes '3' and '11'
# classes '1' and '14'
# classes '3' and '12'
# classes '1' and '16'
# classes '3' and '13'
# classes '2' and '3'
# classes '3' and '14'
# classes '2' and '4'
# classes '3' and '16'
# classes '2' and '5'
# classes '2' and '6'
# classes '4' and '5'
# classes '4' and '6'
# classes '2' and '8'
# classes '4' and '8'
# classes '4' and '9'
# classes '2' and '9'
# classes '4' and '10'
# classes '2' and '10'
# classes '4' and '11'
# classes '2' and '11'
# classes '4' and '12'
# classes '2' and '12'
# classes '4' and '13'
# classes '4' and '14'
# classes '2' and '13'
# classes '4' and '16'
# classes '2' and '14'
# classes '2' and '16'
# classes '5' and '6'
# classes '3' and '4'
# classes '5' and '8'
# classes '3' and '5'
# classes '5' and '9'
# classes '5' and '10'
# classes '3' and '6'
# classes '5' and '11'
# classes '5' and '12'
# classes '5' and '13'
# classes '3' and '8'
# classes '5' and '14'
# classes '5' and '16'
# classes '3' and '9'
# classes '6' and '8'
# classes '3' and '10'
# classes '6' and '9'
# classes '6' and '10'
# classes '6' and '11'
# classes '3' and '11'
# classes '6' and '12'
# classes '6' and '13'
# classes '3' and '12'
# classes '6' and '14'
# classes '6' and '16'
# classes '3' and '13'
# classes '3' and '14'
# classes '8' and '9'
# classes '8' and '10'
# classes '3' and '16'
# classes '4' and '5'
# classes '8' and '11'
# classes '4' and '6'
# classes '8' and '12'
# classes '4' and '8'
# classes '8' and '13'
# classes '4' and '9'
# classes '4' and '10'
# classes '8' and '14'
# classes '4' and '11'
# classes '4' and '12'
# classes '4' and '13'
# classes '8' and '16'
# classes '4' and '14'
# classes '4' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '5' and '6'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '14'
# classes '5' and '8'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '12'
# classes '10' and '13'
# classes '5' and '9'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '12'
# classes '5' and '10'
# classes '11' and '13'
# classes '11' and '14'
# classes '5' and '11'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '5' and '12'
# classes '12' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '5' and '13'
# classes '14' and '16'
# classes '5' and '14'
# classes '5' and '16'
# classes '6' and '8'
# classes '6' and '9'
# classes '6' and '10'
# classes '6' and '11'
# classes '6' and '12'
# classes '6' and '13'
# classes '6' and '14'
# classes '6' and '16'
# classes '8' and '9'
# classes '8' and '10'
# classes '8' and '11'
# classes '8' and '12'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '12'
# classes '10' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:   15.2s finished
#   Finished evaluations for outer fold 'BEATAML1.0-COHORT'.
#
# --- Outer Loop: Holding out Study 'AAML0531' for Testing ---
# Outer training set contains studies: ['AAML1031', 'BEATAML1.0-COHORT', 'LEUCEGENE', 'TCGA-LAML']
#   Inner Loop: Validating on Study 'AAML1031'
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '3'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '4'
# classes '0' and '7'
# classes '0' and '7'
# classes '0' and '8'
# classes '0' and '8'
# classes '0' and '9'
# classes '0' and '9'
# classes '0' and '11'
# classes '0' and '11'
# classes '0' and '12'
# classes '0' and '12'
# classes '0' and '13'
# classes '0' and '16'
# classes '0' and '13'
# classes '0' and '16'
# classes '3' and '4'
# classes '3' and '7'
# classes '3' and '4'
# classes '3' and '8'
# classes '3' and '7'
# classes '3' and '9'
# classes '3' and '8'
# classes '3' and '11'
# classes '3' and '12'
# classes '3' and '9'
# classes '3' and '13'
# classes '3' and '11'
# classes '3' and '16'
# classes '3' and '12'
# classes '4' and '7'
# classes '3' and '13'
# classes '4' and '8'
# classes '3' and '16'
# classes '4' and '9'
# classes '4' and '7'
# classes '4' and '11'
# classes '4' and '12'
# classes '4' and '8'
# classes '4' and '13'
# classes '4' and '9'
# classes '4' and '16'
# classes '4' and '11'
# classes '4' and '12'
# classes '4' and '13'
# classes '7' and '8'
# classes '4' and '16'
# classes '7' and '9'
# classes '7' and '11'
# classes '7' and '12'
# classes '7' and '8'
# classes '7' and '13'
# classes '7' and '9'
# classes '7' and '16'
# classes '7' and '11'
# classes '7' and '12'
# classes '8' and '9'
# classes '7' and '13'
# classes '7' and '16'
# classes '8' and '11'
# classes '8' and '12'
# classes '8' and '9'
# classes '8' and '13'
# classes '8' and '11'
# classes '8' and '16'
# classes '8' and '12'
# classes '9' and '11'
# classes '8' and '13'
# classes '9' and '12'
# classes '8' and '16'
# classes '9' and '13'
# classes '9' and '11'
# classes '9' and '16'
# classes '9' and '12'
# classes '11' and '12'
# classes '9' and '13'
# classes '11' and '13'
# classes '9' and '16'
# classes '11' and '16'
# classes '12' and '13'
# classes '11' and '12'
# classes '12' and '16'
# classes '11' and '13'
# classes '13' and '16'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '16'
# classes '13' and '16'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:    2.6s finished
#   Inner Loop: Validating on Study 'BEATAML1.0-COHORT'
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '1'
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '2'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '5'
# classes '0' and '6'
# classes '0' and '8'
# classes '0' and '5'
# classes '0' and '6'
# classes '0' and '9'
# classes '0' and '10'
# classes '0' and '11'
# classes '0' and '13'
# classes '0' and '8'
# classes '0' and '14'
# classes '0' and '16'
# classes '1' and '2'
# classes '1' and '3'
# classes '1' and '4'
# classes '0' and '9'
# classes '1' and '5'
# classes '0' and '10'
# classes '1' and '6'
# classes '0' and '11'
# classes '1' and '8'
# classes '1' and '9'
# classes '0' and '13'
# classes '1' and '10'
# classes '0' and '14'
# classes '1' and '11'
# classes '1' and '13'
# classes '0' and '16'
# classes '1' and '14'
# classes '1' and '2'
# classes '1' and '16'
# classes '2' and '3'
# classes '2' and '4'
# classes '1' and '3'
# classes '2' and '5'
# classes '1' and '4'
# classes '2' and '6'
# classes '2' and '8'
# classes '2' and '9'
# classes '2' and '10'
# classes '2' and '11'
# classes '2' and '13'
# classes '1' and '5'
# classes '2' and '14'
# classes '2' and '16'
# classes '3' and '4'
# classes '1' and '6'
# classes '3' and '5'
# classes '1' and '8'
# classes '3' and '6'
# classes '1' and '9'
# classes '3' and '8'
# classes '1' and '10'
# classes '3' and '9'
# classes '3' and '10'
# classes '1' and '11'
# classes '3' and '11'
# classes '1' and '13'
# classes '3' and '13'
# classes '1' and '14'
# classes '3' and '14'
# classes '1' and '16'
# classes '3' and '16'
# classes '2' and '3'
# classes '4' and '5'
# classes '2' and '4'
# classes '4' and '6'
# classes '4' and '8'
# classes '2' and '5'
# classes '4' and '9'
# classes '4' and '10'
# classes '2' and '6'
# classes '4' and '11'
# classes '2' and '8'
# classes '4' and '13'
# classes '4' and '14'
# classes '2' and '9'
# classes '4' and '16'
# classes '2' and '10'
# classes '2' and '11'
# classes '2' and '13'
# classes '5' and '6'
# classes '2' and '14'
# classes '2' and '16'
# classes '3' and '4'
# classes '5' and '8'
# classes '5' and '9'
# classes '3' and '5'
# classes '5' and '10'
# classes '3' and '6'
# classes '5' and '11'
# classes '3' and '8'
# classes '5' and '13'
# classes '5' and '14'
# classes '3' and '9'
# classes '5' and '16'
# classes '3' and '10'
# classes '6' and '8'
# classes '3' and '11'
# classes '3' and '13'
# classes '6' and '9'
# classes '6' and '10'
# classes '3' and '14'
# classes '6' and '11'
# classes '3' and '16'
# classes '6' and '13'
# classes '6' and '14'
# classes '4' and '5'
# classes '6' and '16'
# classes '4' and '6'
# classes '4' and '8'
# classes '8' and '9'
# classes '4' and '9'
# classes '8' and '10'
# classes '4' and '10'
# classes '4' and '11'
# classes '8' and '11'
# classes '4' and '13'
# classes '4' and '14'
# classes '8' and '13'
# classes '4' and '16'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '5' and '6'
# classes '9' and '11'
# classes '9' and '13'
# classes '9' and '14'
# classes '5' and '8'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '13'
# classes '5' and '9'
# classes '11' and '14'
# classes '11' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '5' and '10'
# classes '14' and '16'
# classes '5' and '11'
# classes '5' and '13'
# classes '5' and '14'
# classes '5' and '16'
# classes '6' and '8'
# classes '6' and '9'
# classes '6' and '10'
# classes '6' and '11'
# classes '6' and '13'
# classes '6' and '14'
# classes '6' and '16'
# classes '8' and '9'
# classes '8' and '10'
# classes '8' and '11'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:    9.8s finished
#   Inner Loop: Validating on Study 'LEUCEGENE'
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '1'
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '2'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '5'
# classes '0' and '6'
# classes '0' and '7'
# classes '0' and '5'
# classes '0' and '8'
# classes '0' and '6'
# classes '0' and '7'
# classes '0' and '9'
# classes '0' and '10'
# classes '0' and '11'
# classes '0' and '8'
# classes '0' and '12'
# classes '0' and '13'
# classes '0' and '14'
# classes '0' and '16'
# classes '1' and '2'
# classes '0' and '9'
# classes '1' and '3'
# classes '1' and '4'
# classes '0' and '10'
# classes '1' and '5'
# classes '0' and '11'
# classes '1' and '6'
# classes '0' and '12'
# classes '1' and '7'
# classes '1' and '8'
# classes '0' and '13'
# classes '0' and '14'
# classes '1' and '9'
# classes '1' and '10'
# classes '0' and '16'
# classes '1' and '11'
# classes '1' and '2'
# classes '1' and '12'
# classes '1' and '13'
# classes '1' and '14'
# classes '1' and '3'
# classes '1' and '16'
# classes '1' and '4'
# classes '2' and '3'
# classes '2' and '4'
# classes '2' and '5'
# classes '2' and '6'
# classes '2' and '7'
# classes '2' and '8'
# classes '1' and '5'
# classes '2' and '9'
# classes '2' and '10'
# classes '2' and '11'
# classes '1' and '6'
# classes '2' and '12'
# classes '2' and '13'
# classes '1' and '7'
# classes '2' and '14'
# classes '2' and '16'
# classes '3' and '4'
# classes '1' and '8'
# classes '3' and '5'
# classes '3' and '6'
# classes '1' and '9'
# classes '3' and '7'
# classes '1' and '10'
# classes '3' and '8'
# classes '1' and '11'
# classes '3' and '9'
# classes '3' and '10'
# classes '1' and '12'
# classes '3' and '11'
# classes '1' and '13'
# classes '3' and '12'
# classes '3' and '13'
# classes '1' and '14'
# classes '3' and '14'
# classes '1' and '16'
# classes '3' and '16'
# classes '2' and '3'
# classes '2' and '4'
# classes '4' and '5'
# classes '4' and '6'
# classes '4' and '7'
# classes '2' and '5'
# classes '4' and '8'
# classes '2' and '6'
# classes '4' and '9'
# classes '2' and '7'
# classes '4' and '10'
# classes '4' and '11'
# classes '2' and '8'
# classes '4' and '12'
# classes '2' and '9'
# classes '4' and '13'
# classes '4' and '14'
# classes '2' and '10'
# classes '4' and '16'
# classes '2' and '11'
# classes '2' and '12'
# classes '2' and '13'
# classes '5' and '6'
# classes '2' and '14'
# classes '2' and '16'
# classes '5' and '7'
# classes '3' and '4'
# classes '5' and '8'
# classes '3' and '5'
# classes '5' and '9'
# classes '3' and '6'
# classes '5' and '10'
# classes '3' and '7'
# classes '5' and '11'
# classes '5' and '12'
# classes '3' and '8'
# classes '5' and '13'
# classes '3' and '9'
# classes '5' and '14'
# classes '3' and '10'
# classes '5' and '16'
# classes '6' and '7'
# classes '3' and '11'
# classes '6' and '8'
# classes '3' and '12'
# classes '6' and '9'
# classes '3' and '13'
# classes '6' and '10'
# classes '3' and '14'
# classes '6' and '11'
# classes '6' and '12'
# classes '3' and '16'
# classes '6' and '13'
# classes '6' and '14'
# classes '4' and '5'
# classes '6' and '16'
# classes '4' and '6'
# classes '7' and '8'
# classes '4' and '7'
# classes '7' and '9'
# classes '4' and '8'
# classes '7' and '10'
# classes '7' and '11'
# classes '4' and '9'
# classes '7' and '12'
# classes '4' and '10'
# classes '7' and '13'
# classes '4' and '11'
# classes '7' and '14'
# classes '4' and '12'
# classes '7' and '16'
# classes '4' and '13'
# classes '4' and '14'
# classes '4' and '16'
# classes '8' and '9'
# classes '8' and '10'
# classes '8' and '11'
# classes '5' and '6'
# classes '8' and '12'
# classes '5' and '7'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '5' and '8'
# classes '9' and '11'
# classes '9' and '12'
# classes '5' and '9'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '5' and '10'
# classes '10' and '11'
# classes '10' and '12'
# classes '10' and '13'
# classes '10' and '14'
# classes '5' and '11'
# classes '10' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '5' and '12'
# classes '11' and '14'
# classes '11' and '16'
# classes '12' and '13'
# classes '5' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '13' and '14'
# classes '5' and '14'
# classes '13' and '16'
# classes '14' and '16'
# classes '5' and '16'
# classes '6' and '7'
# classes '6' and '8'
# classes '6' and '9'
# classes '6' and '10'
# classes '6' and '11'
# classes '6' and '12'
# classes '6' and '13'
# classes '6' and '14'
# classes '6' and '16'
# classes '7' and '8'
# classes '7' and '9'
# classes '7' and '10'
# classes '7' and '11'
# classes '7' and '12'
# classes '7' and '13'
# classes '7' and '14'
# classes '7' and '16'
# classes '8' and '9'
# classes '8' and '10'
# classes '8' and '11'
# classes '8' and '12'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '12'
# classes '10' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
#   Inner Loop: Validating on Study 'TCGA-LAML'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:   12.9s finished
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '5'
# classes '0' and '6'
# classes '0' and '5'
# classes '0' and '8'
# classes '0' and '6'
# classes '0' and '9'
# classes '0' and '10'
# classes '0' and '11'
# classes '0' and '12'
# classes '0' and '8'
# classes '0' and '13'
# classes '0' and '14'
# classes '0' and '16'
# classes '1' and '2'
# classes '1' and '3'
# classes '0' and '9'
# classes '1' and '4'
# classes '0' and '10'
# classes '0' and '11'
# classes '1' and '5'
# classes '0' and '12'
# classes '1' and '6'
# classes '0' and '13'
# classes '0' and '14'
# classes '1' and '8'
# classes '0' and '16'
# classes '1' and '2'
# classes '1' and '9'
# classes '1' and '10'
# classes '1' and '11'
# classes '1' and '3'
# classes '1' and '12'
# classes '1' and '4'
# classes '1' and '13'
# classes '1' and '14'
# classes '1' and '16'
# classes '2' and '3'
# classes '2' and '4'
# classes '2' and '5'
# classes '2' and '6'
# classes '2' and '8'
# classes '1' and '5'
# classes '2' and '9'
# classes '2' and '10'
# classes '2' and '11'
# classes '2' and '12'
# classes '2' and '13'
# classes '2' and '14'
# classes '2' and '16'
# classes '1' and '6'
# classes '3' and '4'
# classes '3' and '5'
# classes '1' and '8'
# classes '3' and '6'
# classes '3' and '8'
# classes '1' and '9'
# classes '3' and '9'
# classes '1' and '10'
# classes '3' and '10'
# classes '3' and '11'
# classes '1' and '11'
# classes '3' and '12'
# classes '1' and '12'
# classes '3' and '13'
# classes '3' and '14'
# classes '1' and '13'
# classes '3' and '16'
# classes '1' and '14'
# classes '4' and '5'
# classes '1' and '16'
# classes '4' and '6'
# classes '2' and '3'
# classes '4' and '8'
# classes '2' and '4'
# classes '4' and '9'
# classes '4' and '10'
# classes '4' and '11'
# classes '2' and '5'
# classes '4' and '12'
# classes '4' and '13'
# classes '2' and '6'
# classes '4' and '14'
# classes '4' and '16'
# classes '2' and '8'
# classes '2' and '9'
# classes '2' and '10'
# classes '2' and '11'
# classes '5' and '6'
# classes '2' and '12'
# classes '2' and '13'
# classes '2' and '14'
# classes '2' and '16'
# classes '5' and '8'
# classes '3' and '4'
# classes '5' and '9'
# classes '3' and '5'
# classes '5' and '10'
# classes '3' and '6'
# classes '5' and '11'
# classes '5' and '12'
# classes '3' and '8'
# classes '5' and '13'
# classes '3' and '9'
# classes '5' and '14'
# classes '3' and '10'
# classes '3' and '11'
# classes '5' and '16'
# classes '3' and '12'
# classes '6' and '8'
# classes '3' and '13'
# classes '6' and '9'
# classes '3' and '14'
# classes '6' and '10'
# classes '3' and '16'
# classes '6' and '11'
# classes '6' and '12'
# classes '6' and '13'
# classes '4' and '5'
# classes '6' and '14'
# classes '6' and '16'
# classes '4' and '6'
# classes '4' and '8'
# classes '8' and '9'
# classes '4' and '9'
# classes '4' and '10'
# classes '8' and '10'
# classes '4' and '11'
# classes '8' and '11'
# classes '4' and '12'
# classes '4' and '13'
# classes '8' and '12'
# classes '4' and '14'
# classes '4' and '16'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '5' and '6'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '5' and '8'
# classes '10' and '11'
# classes '10' and '12'
# classes '10' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '5' and '9'
# classes '11' and '14'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '5' and '10'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# classes '5' and '11'
# classes '5' and '12'
# classes '5' and '13'
# classes '5' and '14'
# classes '5' and '16'
# classes '6' and '8'
# classes '6' and '9'
# classes '6' and '10'
# classes '6' and '11'
# classes '6' and '12'
# classes '6' and '13'
# classes '6' and '14'
# classes '6' and '16'
# classes '8' and '9'
# classes '8' and '10'
# classes '8' and '11'
# classes '8' and '12'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '12'
# classes '10' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:   16.4s finished
#   Finished evaluations for outer fold 'AAML0531'.
#
# --- Outer Loop: Holding out Study 'AAML1031' for Testing ---
# Outer training set contains studies: ['AAML0531', 'BEATAML1.0-COHORT', 'LEUCEGENE', 'TCGA-LAML']
#   Inner Loop: Validating on Study 'AAML0531'
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '1'
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '2'
# classes '0' and '3'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '4'
# classes '0' and '5'
# classes '0' and '5'
# classes '0' and '6'
# classes '0' and '7'
# classes '0' and '6'
# classes '0' and '7'
# classes '0' and '8'
# classes '0' and '9'
# classes '0' and '8'
# classes '0' and '11'
# classes '0' and '9'
# classes '0' and '12'
# classes '0' and '11'
# classes '0' and '13'
# classes '0' and '12'
# classes '0' and '14'
# classes '0' and '13'
# classes '0' and '16'
# classes '0' and '14'
# classes '0' and '16'
# classes '1' and '2'
# classes '1' and '2'
# classes '1' and '3'
# classes '1' and '4'
# classes '1' and '3'
# classes '1' and '4'
# classes '1' and '5'
# classes '1' and '5'
# classes '1' and '6'
# classes '1' and '7'
# classes '1' and '8'
# classes '1' and '9'
# classes '1' and '6'
# classes '1' and '11'
# classes '1' and '7'
# classes '1' and '12'
# classes '1' and '13'
# classes '1' and '8'
# classes '1' and '14'
# classes '1' and '9'
# classes '1' and '16'
# classes '2' and '3'
# classes '2' and '4'
# classes '1' and '11'
# classes '1' and '12'
# classes '2' and '5'
# classes '2' and '6'
# classes '1' and '13'
# classes '2' and '7'
# classes '2' and '8'
# classes '2' and '9'
# classes '1' and '14'
# classes '2' and '11'
# classes '2' and '12'
# classes '2' and '13'
# classes '1' and '16'
# classes '2' and '14'
# classes '2' and '3'
# classes '2' and '16'
# classes '2' and '4'
# classes '3' and '4'
# classes '2' and '5'
# classes '3' and '5'
# classes '3' and '6'
# classes '2' and '6'
# classes '2' and '7'
# classes '3' and '7'
# classes '2' and '8'
# classes '3' and '8'
# classes '3' and '9'
# classes '2' and '9'
# classes '2' and '11'
# classes '3' and '11'
# classes '2' and '12'
# classes '3' and '12'
# classes '2' and '13'
# classes '3' and '13'
# classes '2' and '14'
# classes '3' and '14'
# classes '2' and '16'
# classes '3' and '4'
# classes '3' and '16'
# classes '4' and '5'
# classes '4' and '6'
# classes '4' and '7'
# classes '4' and '8'
# classes '3' and '5'
# classes '4' and '9'
# classes '4' and '11'
# classes '4' and '12'
# classes '3' and '6'
# classes '4' and '13'
# classes '3' and '7'
# classes '4' and '14'
# classes '4' and '16'
# classes '3' and '8'
# classes '3' and '9'
# classes '3' and '11'
# classes '3' and '12'
# classes '3' and '13'
# classes '5' and '6'
# classes '3' and '14'
# classes '3' and '16'
# classes '5' and '7'
# classes '4' and '5'
# classes '5' and '8'
# classes '4' and '6'
# classes '4' and '7'
# classes '4' and '8'
# classes '5' and '9'
# classes '4' and '9'
# classes '4' and '11'
# classes '4' and '12'
# classes '4' and '13'
# classes '4' and '14'
# classes '5' and '11'
# classes '4' and '16'
# classes '5' and '12'
# classes '5' and '13'
# classes '5' and '6'
# classes '5' and '14'
# classes '5' and '7'
# classes '5' and '16'
# classes '6' and '7'
# classes '6' and '8'
# classes '5' and '8'
# classes '6' and '9'
# classes '6' and '11'
# classes '6' and '12'
# classes '6' and '13'
# classes '5' and '9'
# classes '6' and '14'
# classes '6' and '16'
# classes '7' and '8'
# classes '7' and '9'
# classes '5' and '11'
# classes '7' and '11'
# classes '7' and '12'
# classes '7' and '13'
# classes '7' and '14'
# classes '7' and '16'
# classes '5' and '12'
# classes '8' and '9'
# classes '8' and '11'
# classes '8' and '12'
# classes '8' and '13'
# classes '5' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '11'
# classes '9' and '12'
# classes '9' and '13'
# classes '5' and '14'
# classes '9' and '14'
# classes '9' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '14'
# classes '5' and '16'
# classes '11' and '16'
# classes '6' and '7'
# classes '12' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '6' and '8'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# classes '6' and '9'
# classes '6' and '11'
# classes '6' and '12'
# classes '6' and '13'
# classes '6' and '14'
# classes '6' and '16'
# classes '7' and '8'
# classes '7' and '9'
# classes '7' and '11'
# classes '7' and '12'
# classes '7' and '13'
# classes '7' and '14'
# classes '7' and '16'
# classes '8' and '9'
# classes '8' and '11'
# classes '8' and '12'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '11'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:   10.7s finished
#   Inner Loop: Validating on Study 'BEATAML1.0-COHORT'
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '1'
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '2'
# classes '0' and '3'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '4'
# classes '0' and '5'
# classes '0' and '6'
# classes '0' and '5'
# classes '0' and '8'
# classes '0' and '9'
# classes '0' and '6'
# classes '0' and '10'
# classes '0' and '11'
# classes '0' and '8'
# classes '0' and '13'
# classes '0' and '9'
# classes '0' and '14'
# classes '0' and '10'
# classes '0' and '16'
# classes '0' and '11'
# classes '1' and '2'
# classes '0' and '13'
# classes '1' and '3'
# classes '0' and '14'
# classes '1' and '4'
# classes '0' and '16'
# classes '1' and '2'
# classes '1' and '5'
# classes '1' and '6'
# classes '1' and '3'
# classes '1' and '4'
# classes '1' and '8'
# classes '1' and '9'
# classes '1' and '10'
# classes '1' and '11'
# classes '1' and '13'
# classes '1' and '5'
# classes '1' and '14'
# classes '1' and '6'
# classes '1' and '16'
# classes '2' and '3'
# classes '2' and '4'
# classes '1' and '8'
# classes '2' and '5'
# classes '1' and '9'
# classes '2' and '6'
# classes '2' and '8'
# classes '1' and '10'
# classes '2' and '9'
# classes '2' and '10'
# classes '1' and '11'
# classes '2' and '11'
# classes '2' and '13'
# classes '2' and '14'
# classes '1' and '13'
# classes '2' and '16'
# classes '1' and '14'
# classes '3' and '4'
# classes '1' and '16'
# classes '3' and '5'
# classes '2' and '3'
# classes '3' and '6'
# classes '2' and '4'
# classes '3' and '8'
# classes '2' and '5'
# classes '3' and '9'
# classes '2' and '6'
# classes '3' and '10'
# classes '2' and '8'
# classes '3' and '11'
# classes '2' and '9'
# classes '3' and '13'
# classes '2' and '10'
# classes '3' and '14'
# classes '2' and '11'
# classes '2' and '13'
# classes '3' and '16'
# classes '2' and '14'
# classes '4' and '5'
# classes '2' and '16'
# classes '4' and '6'
# classes '3' and '4'
# classes '4' and '8'
# classes '4' and '9'
# classes '4' and '10'
# classes '4' and '11'
# classes '4' and '13'
# classes '4' and '14'
# classes '3' and '5'
# classes '4' and '16'
# classes '3' and '6'
# classes '5' and '6'
# classes '3' and '8'
# classes '5' and '8'
# classes '3' and '9'
# classes '3' and '10'
# classes '5' and '9'
# classes '3' and '11'
# classes '5' and '10'
# classes '3' and '13'
# classes '5' and '11'
# classes '3' and '14'
# classes '3' and '16'
# classes '5' and '13'
# classes '4' and '5'
# classes '5' and '14'
# classes '4' and '6'
# classes '4' and '8'
# classes '4' and '9'
# classes '5' and '16'
# classes '4' and '10'
# classes '4' and '11'
# classes '6' and '8'
# classes '4' and '13'
# classes '4' and '14'
# classes '6' and '9'
# classes '4' and '16'
# classes '6' and '10'
# classes '6' and '11'
# classes '6' and '13'
# classes '6' and '14'
# classes '5' and '6'
# classes '6' and '16'
# classes '8' and '9'
# classes '8' and '10'
# classes '5' and '8'
# classes '8' and '11'
# classes '8' and '13'
# classes '8' and '14'
# classes '5' and '9'
# classes '8' and '16'
# classes '9' and '10'
# classes '5' and '10'
# classes '9' and '11'
# classes '9' and '13'
# classes '9' and '14'
# classes '5' and '11'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '13'
# classes '5' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '13'
# classes '5' and '14'
# classes '11' and '14'
# classes '11' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '5' and '16'
# classes '14' and '16'
# classes '6' and '8'
# classes '6' and '9'
# classes '6' and '10'
# classes '6' and '11'
# classes '6' and '13'
# classes '6' and '14'
# classes '6' and '16'
# classes '8' and '9'
# classes '8' and '10'
# classes '8' and '11'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:   10.0s finished
#   Inner Loop: Validating on Study 'LEUCEGENE'
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '1'
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '2'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '5'
# classes '0' and '6'
# classes '0' and '7'
# classes '0' and '5'
# classes '0' and '8'
# classes '0' and '6'
# classes '0' and '7'
# classes '0' and '9'
# classes '0' and '10'
# classes '0' and '11'
# classes '0' and '8'
# classes '0' and '12'
# classes '0' and '9'
# classes '0' and '13'
# classes '0' and '14'
# classes '0' and '10'
# classes '0' and '11'
# classes '0' and '16'
# classes '0' and '12'
# classes '1' and '2'
# classes '0' and '13'
# classes '0' and '14'
# classes '1' and '3'
# classes '0' and '16'
# classes '1' and '4'
# classes '1' and '2'
# classes '1' and '5'
# classes '1' and '3'
# classes '1' and '4'
# classes '1' and '6'
# classes '1' and '7'
# classes '1' and '8'
# classes '1' and '9'
# classes '1' and '10'
# classes '1' and '5'
# classes '1' and '11'
# classes '1' and '12'
# classes '1' and '6'
# classes '1' and '13'
# classes '1' and '7'
# classes '1' and '14'
# classes '1' and '8'
# classes '1' and '16'
# classes '2' and '3'
# classes '2' and '4'
# classes '1' and '9'
# classes '2' and '5'
# classes '1' and '10'
# classes '2' and '6'
# classes '2' and '7'
# classes '1' and '11'
# classes '2' and '8'
# classes '2' and '9'
# classes '1' and '12'
# classes '2' and '10'
# classes '2' and '11'
# classes '2' and '12'
# classes '1' and '13'
# classes '2' and '13'
# classes '2' and '14'
# classes '1' and '14'
# classes '2' and '16'
# classes '3' and '4'
# classes '1' and '16'
# classes '3' and '5'
# classes '2' and '3'
# classes '2' and '4'
# classes '3' and '6'
# classes '3' and '7'
# classes '2' and '5'
# classes '3' and '8'
# classes '2' and '6'
# classes '3' and '9'
# classes '2' and '7'
# classes '3' and '10'
# classes '2' and '8'
# classes '3' and '11'
# classes '2' and '9'
# classes '3' and '12'
# classes '2' and '10'
# classes '3' and '13'
# classes '2' and '11'
# classes '2' and '12'
# classes '3' and '14'
# classes '2' and '13'
# classes '3' and '16'
# classes '2' and '14'
# classes '4' and '5'
# classes '2' and '16'
# classes '4' and '6'
# classes '4' and '7'
# classes '3' and '4'
# classes '4' and '8'
# classes '4' and '9'
# classes '4' and '10'
# classes '4' and '11'
# classes '4' and '12'
# classes '3' and '5'
# classes '4' and '13'
# classes '4' and '14'
# classes '4' and '16'
# classes '3' and '6'
# classes '3' and '7'
# classes '5' and '6'
# classes '5' and '7'
# classes '3' and '8'
# classes '3' and '9'
# classes '5' and '8'
# classes '3' and '10'
# classes '5' and '9'
# classes '3' and '11'
# classes '3' and '12'
# classes '5' and '10'
# classes '3' and '13'
# classes '5' and '11'
# classes '3' and '14'
# classes '5' and '12'
# classes '3' and '16'
# classes '5' and '13'
# classes '4' and '5'
# classes '4' and '6'
# classes '4' and '7'
# classes '5' and '14'
# classes '4' and '8'
# classes '4' and '9'
# classes '4' and '10'
# classes '4' and '11'
# classes '5' and '16'
# classes '4' and '12'
# classes '6' and '7'
# classes '4' and '13'
# classes '4' and '14'
# classes '6' and '8'
# classes '4' and '16'
# classes '6' and '9'
# classes '6' and '10'
# classes '6' and '11'
# classes '6' and '12'
# classes '5' and '6'
# classes '6' and '13'
# classes '6' and '14'
# classes '5' and '7'
# classes '6' and '16'
# classes '7' and '8'
# classes '7' and '9'
# classes '7' and '10'
# classes '7' and '11'
# classes '5' and '8'
# classes '7' and '12'
# classes '7' and '13'
# classes '7' and '14'
# classes '7' and '16'
# classes '5' and '9'
# classes '8' and '9'
# classes '8' and '10'
# classes '5' and '10'
# classes '8' and '11'
# classes '8' and '12'
# classes '8' and '13'
# classes '5' and '11'
# classes '8' and '14'
# classes '5' and '12'
# classes '8' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '5' and '13'
# classes '9' and '12'
# classes '9' and '13'
# classes '5' and '14'
# classes '9' and '14'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '12'
# classes '5' and '16'
# classes '10' and '13'
# classes '6' and '7'
# classes '10' and '14'
# classes '6' and '8'
# classes '10' and '16'
# classes '11' and '12'
# classes '6' and '9'
# classes '11' and '13'
# classes '11' and '14'
# classes '6' and '10'
# classes '11' and '16'
# classes '6' and '11'
# classes '12' and '13'
# classes '6' and '12'
# classes '12' and '14'
# classes '6' and '13'
# classes '12' and '16'
# classes '6' and '14'
# classes '13' and '14'
# classes '13' and '16'
# classes '6' and '16'
# classes '14' and '16'
# classes '7' and '8'
# classes '7' and '9'
# classes '7' and '10'
# classes '7' and '11'
# classes '7' and '12'
# classes '7' and '13'
# classes '7' and '14'
# classes '7' and '16'
# classes '8' and '9'
# classes '8' and '10'
# classes '8' and '11'
# classes '8' and '12'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '12'
# classes '10' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
#   Inner Loop: Validating on Study 'TCGA-LAML'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:   10.1s finished
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '1'
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '2'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '5'
# classes '0' and '6'
# classes '0' and '5'
# classes '0' and '8'
# classes '0' and '9'
# classes '0' and '6'
# classes '0' and '10'
# classes '0' and '11'
# classes '0' and '8'
# classes '0' and '12'
# classes '0' and '13'
# classes '0' and '9'
# classes '0' and '14'
# classes '0' and '10'
# classes '0' and '16'
# classes '0' and '11'
# classes '1' and '2'
# classes '0' and '12'
# classes '0' and '13'
# classes '1' and '3'
# classes '0' and '14'
# classes '1' and '4'
# classes '0' and '16'
# classes '1' and '2'
# classes '1' and '3'
# classes '1' and '5'
# classes '1' and '4'
# classes '1' and '6'
# classes '1' and '8'
# classes '1' and '9'
# classes '1' and '5'
# classes '1' and '10'
# classes '1' and '11'
# classes '1' and '12'
# classes '1' and '13'
# classes '1' and '6'
# classes '1' and '14'
# classes '1' and '16'
# classes '1' and '8'
# classes '2' and '3'
# classes '2' and '4'
# classes '1' and '9'
# classes '2' and '5'
# classes '2' and '6'
# classes '1' and '10'
# classes '2' and '8'
# classes '2' and '9'
# classes '1' and '11'
# classes '2' and '10'
# classes '2' and '11'
# classes '1' and '12'
# classes '2' and '12'
# classes '2' and '13'
# classes '2' and '14'
# classes '1' and '13'
# classes '2' and '16'
# classes '3' and '4'
# classes '1' and '14'
# classes '3' and '5'
# classes '1' and '16'
# classes '3' and '6'
# classes '2' and '3'
# classes '2' and '4'
# classes '3' and '8'
# classes '3' and '9'
# ...
# classes '2' and '11'
# classes '2' and '12'
# classes '2' and '13'
# classes '1' and '6'
# classes '2' and '14'
# classes '2' and '16'
# classes '1' and '7'
# classes '3' and '4'
# classes '3' and '5'
# classes '1' and '8'
# classes '3' and '6'
# classes '3' and '7'
# classes '1' and '9'
# classes '3' and '8'
# classes '1' and '11'
# classes '1' and '12'
# classes '3' and '9'
# classes '3' and '11'
# classes '1' and '13'
# classes '1' and '14'
# classes '3' and '12'
# classes '3' and '13'
# classes '1' and '16'
# classes '3' and '14'
# classes '2' and '3'
# classes '2' and '4'
# classes '3' and '16'
# classes '4' and '5'
# classes '2' and '5'
# classes '4' and '6'
# classes '4' and '7'
# classes '2' and '6'
# classes '2' and '7'
# classes '4' and '8'
# classes '4' and '9'
# classes '2' and '8'
# classes '4' and '11'
# classes '4' and '12'
# classes '4' and '13'
# classes '2' and '9'
# classes '4' and '14'
# classes '2' and '11'
# classes '4' and '16'
# classes '2' and '12'
# classes '2' and '13'
# classes '5' and '6'
# classes '2' and '14'
# classes '2' and '16'
# classes '5' and '7'
# classes '3' and '4'
# classes '5' and '8'
# classes '3' and '5'
# classes '5' and '9'
# classes '3' and '6'
# classes '5' and '11'
# classes '3' and '7'
# classes '5' and '12'
# classes '5' and '13'
# classes '5' and '14'
# classes '3' and '8'
# classes '5' and '16'
# classes '6' and '7'
# classes '3' and '9'
# classes '6' and '8'
# classes '3' and '11'
# classes '6' and '9'
# classes '3' and '12'
# classes '6' and '11'
# classes '6' and '12'
# classes '6' and '13'
# classes '3' and '13'
# classes '6' and '14'
# classes '6' and '16'
# classes '3' and '14'
# classes '7' and '8'
# classes '3' and '16'
# classes '7' and '9'
# classes '7' and '11'
# classes '4' and '5'
# classes '7' and '12'
# classes '4' and '6'
# classes '7' and '13'
# classes '4' and '7'
# classes '7' and '14'
# classes '7' and '16'
# classes '4' and '8'
# classes '8' and '9'
# classes '4' and '9'
# classes '4' and '11'
# classes '8' and '11'
# classes '4' and '12'
# classes '4' and '13'
# classes '8' and '12'
# classes '4' and '14'
# classes '4' and '16'
# classes '8' and '13'
# classes '8' and '14'
# classes '5' and '6'
# classes '8' and '16'
# classes '9' and '11'
# classes '5' and '7'
# classes '9' and '12'
# classes '9' and '13'
# classes '5' and '8'
# classes '9' and '14'
# classes '9' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '14'
# classes '5' and '9'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '5' and '11'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# classes '5' and '12'
# classes '5' and '13'
# classes '5' and '14'
# classes '5' and '16'
# classes '6' and '7'
# classes '6' and '8'
# classes '6' and '9'
# classes '6' and '11'
# classes '6' and '12'
# classes '6' and '13'
# classes '6' and '14'
# classes '6' and '16'
# classes '7' and '8'
# classes '7' and '9'
# classes '7' and '11'
# classes '7' and '12'
# classes '7' and '13'
# classes '7' and '14'
# classes '7' and '16'
# classes '8' and '9'
# classes '8' and '11'
# classes '8' and '12'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '11'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:   11.1s finished
#   Inner Loop: Validating on Study 'AAML1031'
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '3'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '4'
# classes '0' and '7'
# classes '0' and '7'
# classes '0' and '8'
# classes '0' and '8'
# classes '0' and '9'
# classes '0' and '11'
# classes '0' and '9'
# classes '0' and '12'
# classes '0' and '11'
# classes '0' and '13'
# classes '0' and '12'
# classes '0' and '16'
# classes '0' and '13'
# classes '3' and '4'
# classes '0' and '16'
# classes '3' and '7'
# classes '3' and '4'
# classes '3' and '8'
# classes '3' and '7'
# classes '3' and '9'
# classes '3' and '11'
# classes '3' and '12'
# classes '3' and '8'
# classes '3' and '13'
# classes '3' and '9'
# classes '3' and '11'
# classes '3' and '16'
# classes '3' and '12'
# classes '4' and '7'
# classes '4' and '8'
# classes '3' and '13'
# classes '4' and '9'
# classes '4' and '11'
# classes '4' and '12'
# classes '3' and '16'
# classes '4' and '13'
# classes '4' and '7'
# classes '4' and '16'
# classes '4' and '8'
# classes '4' and '9'
# classes '7' and '8'
# classes '4' and '11'
# classes '7' and '9'
# classes '4' and '12'
# classes '7' and '11'
# classes '4' and '13'
# classes '7' and '12'
# classes '4' and '16'
# classes '7' and '13'
# classes '7' and '16'
# classes '7' and '8'
# classes '8' and '9'
# classes '7' and '9'
# classes '8' and '11'
# classes '7' and '11'
# classes '8' and '12'
# classes '7' and '12'
# classes '7' and '13'
# classes '8' and '13'
# classes '7' and '16'
# classes '8' and '16'
# classes '9' and '11'
# classes '8' and '9'
# classes '9' and '12'
# classes '8' and '11'
# classes '9' and '13'
# classes '8' and '12'
# classes '9' and '16'
# classes '11' and '12'
# classes '8' and '13'
# classes '11' and '13'
# classes '11' and '16'
# classes '12' and '13'
# classes '8' and '16'
# classes '12' and '16'
# classes '9' and '11'
# classes '13' and '16'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '16'
# classes '13' and '16'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:    4.4s finished
#   Inner Loop: Validating on Study 'BEATAML1.0-COHORT'
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '1'
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '2'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '3'
# classes '0' and '5'
# classes '0' and '4'
# classes '0' and '6'
# classes '0' and '5'
# classes '0' and '8'
# classes '0' and '6'
# classes '0' and '9'
# classes '0' and '10'
# classes '0' and '11'
# classes '0' and '13'
# classes '0' and '8'
# classes '0' and '14'
# classes '0' and '16'
# classes '1' and '2'
# classes '1' and '3'
# classes '1' and '4'
# classes '0' and '9'
# classes '1' and '5'
# classes '1' and '6'
# classes '0' and '10'
# classes '1' and '8'
# classes '1' and '9'
# classes '1' and '10'
# classes '1' and '11'
# classes '1' and '13'
# classes '0' and '11'
# classes '1' and '14'
# classes '1' and '16'
# classes '2' and '3'
# classes '0' and '13'
# classes '2' and '4'
# classes '2' and '5'
# classes '2' and '6'
# classes '0' and '14'
# classes '2' and '8'
# classes '2' and '9'
# classes '2' and '10'
# classes '2' and '11'
# classes '2' and '13'
# classes '2' and '14'
# classes '0' and '16'
# classes '2' and '16'
# classes '1' and '2'
# classes '3' and '4'
# classes '1' and '3'
# classes '3' and '5'
# classes '1' and '4'
# classes '3' and '6'
# classes '1' and '5'
# classes '1' and '6'
# classes '3' and '8'
# classes '1' and '8'
# classes '3' and '9'
# classes '3' and '10'
# classes '1' and '9'
# classes '1' and '10'
# classes '3' and '11'
# classes '1' and '11'
# classes '3' and '13'
# classes '1' and '13'
# classes '1' and '14'
# classes '3' and '14'
# classes '1' and '16'
# classes '3' and '16'
# classes '4' and '5'
# classes '2' and '3'
# classes '4' and '6'
# classes '2' and '4'
# classes '4' and '8'
# classes '2' and '5'
# classes '4' and '9'
# classes '2' and '6'
# classes '4' and '10'
# classes '4' and '11'
# classes '4' and '13'
# classes '2' and '8'
# classes '4' and '14'
# classes '4' and '16'
# classes '2' and '9'
# classes '5' and '6'
# classes '2' and '10'
# classes '2' and '11'
# classes '2' and '13'
# classes '5' and '8'
# classes '2' and '14'
# classes '2' and '16'
# classes '5' and '9'
# classes '5' and '10'
# classes '3' and '4'
# classes '5' and '11'
# classes '5' and '13'
# classes '3' and '5'
# classes '5' and '14'
# classes '5' and '16'
# classes '3' and '6'
# classes '6' and '8'
# classes '6' and '9'
# classes '6' and '10'
# classes '6' and '11'
# classes '6' and '13'
# classes '3' and '8'
# classes '6' and '14'
# classes '6' and '16'
# classes '3' and '9'
# classes '8' and '9'
# classes '8' and '10'
# classes '3' and '10'
# classes '8' and '11'
# classes '3' and '11'
# classes '8' and '13'
# classes '3' and '13'
# classes '8' and '14'
# classes '3' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '3' and '16'
# classes '9' and '11'
# classes '4' and '5'
# classes '4' and '6'
# classes '9' and '13'
# classes '4' and '8'
# classes '9' and '14'
# classes '4' and '9'
# classes '9' and '16'
# classes '4' and '10'
# classes '10' and '11'
# classes '4' and '11'
# classes '10' and '13'
# classes '4' and '13'
# classes '10' and '14'
# classes '4' and '14'
# classes '10' and '16'
# classes '4' and '16'
# classes '11' and '13'
# classes '11' and '14'
# classes '5' and '6'
# classes '11' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# classes '5' and '8'
# classes '5' and '9'
# classes '5' and '10'
# classes '5' and '11'
# classes '5' and '13'
# classes '5' and '14'
# classes '5' and '16'
# classes '6' and '8'
# classes '6' and '9'
# classes '6' and '10'
# classes '6' and '11'
# classes '6' and '13'
# classes '6' and '14'
# classes '6' and '16'
# classes '8' and '9'
# classes '8' and '10'
# classes '8' and '11'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
#   Inner Loop: Validating on Study 'TCGA-LAML'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:   10.6s finished
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# classes '0' and '1'
# classes '0' and '1'
# classes '0' and '2'
# classes '0' and '2'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '3'
# classes '0' and '4'
# classes '0' and '5'
# classes '0' and '6'
# classes '0' and '5'
# classes '0' and '8'
# classes '0' and '6'
# classes '0' and '9'
# classes '0' and '10'
# classes '0' and '11'
# classes '0' and '12'
# classes '0' and '8'
# classes '0' and '13'
# classes '0' and '14'
# classes '0' and '16'
# classes '1' and '2'
# classes '0' and '9'
# classes '1' and '3'
# classes '0' and '10'
# classes '1' and '4'
# classes '1' and '5'
# classes '0' and '11'
# classes '1' and '6'
# classes '0' and '12'
# classes '1' and '8'
# classes '1' and '9'
# classes '1' and '10'
# classes '0' and '13'
# classes '1' and '11'
# classes '1' and '12'
# classes '0' and '14'
# classes '1' and '13'
# classes '1' and '14'
# classes '1' and '16'
# classes '2' and '3'
# classes '0' and '16'
# classes '2' and '4'
# classes '1' and '2'
# classes '2' and '5'
# classes '2' and '6'
# classes '2' and '8'
# classes '1' and '3'
# classes '2' and '9'
# classes '2' and '10'
# classes '1' and '4'
# classes '2' and '11'
# classes '2' and '12'
# classes '2' and '13'
# classes '2' and '14'
# classes '2' and '16'
# classes '3' and '4'
# classes '1' and '5'
# classes '1' and '6'
# classes '3' and '5'
# classes '3' and '6'
# classes '1' and '8'
# classes '3' and '8'
# classes '1' and '9'
# classes '3' and '9'
# classes '1' and '10'
# classes '3' and '10'
# classes '1' and '11'
# classes '3' and '11'
# classes '1' and '12'
# classes '3' and '12'
# classes '1' and '13'
# classes '3' and '13'
# classes '1' and '14'
# classes '3' and '14'
# classes '1' and '16'
# classes '3' and '16'
# classes '2' and '3'
# classes '4' and '5'
# classes '2' and '4'
# classes '4' and '6'
# classes '4' and '8'
# classes '2' and '5'
# classes '4' and '9'
# classes '2' and '6'
# classes '4' and '10'
# classes '4' and '11'
# classes '4' and '12'
# classes '4' and '13'
# classes '2' and '8'
# classes '4' and '14'
# classes '4' and '16'
# classes '2' and '9'
# classes '2' and '10'
# classes '5' and '6'
# classes '2' and '11'
# classes '2' and '12'
# classes '2' and '13'
# classes '2' and '14'
# classes '5' and '8'
# classes '2' and '16'
# classes '3' and '4'
# classes '5' and '9'
# classes '5' and '10'
# classes '5' and '11'
# classes '3' and '5'
# classes '5' and '12'
# classes '3' and '6'
# classes '5' and '13'
# classes '5' and '14'
# classes '5' and '16'
# classes '3' and '8'
# classes '6' and '8'
# classes '6' and '9'
# classes '6' and '10'
# classes '6' and '11'
# classes '3' and '9'
# classes '6' and '12'
# classes '6' and '13'
# classes '3' and '10'
# classes '6' and '14'
# classes '6' and '16'
# classes '3' and '11'
# classes '3' and '12'
# classes '8' and '9'
# classes '8' and '10'
# classes '3' and '13'
# classes '8' and '11'
# classes '3' and '14'
# classes '8' and '12'
# classes '8' and '13'
# classes '3' and '16'
# classes '8' and '14'
# classes '4' and '5'
# classes '4' and '6'
# classes '8' and '16'
# classes '9' and '10'
# classes '4' and '8'
# classes '9' and '11'
# classes '4' and '9'
# classes '4' and '10'
# classes '4' and '11'
# classes '9' and '12'
# classes '4' and '12'
# classes '4' and '13'
# classes '4' and '14'
# classes '9' and '13'
# classes '4' and '16'
# classes '9' and '14'
# classes '9' and '16'
# classes '5' and '6'
# classes '10' and '11'
# classes '10' and '12'
# classes '10' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '12'
# classes '5' and '8'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '5' and '9'
# classes '12' and '16'
# classes '13' and '14'
# classes '5' and '10'
# classes '13' and '16'
# classes '14' and '16'
# classes '5' and '11'
# classes '5' and '12'
# classes '5' and '13'
# classes '5' and '14'
# classes '5' and '16'
# classes '6' and '8'
# classes '6' and '9'
# classes '6' and '10'
# classes '6' and '11'
# classes '6' and '12'
# classes '6' and '13'
# classes '6' and '14'
# classes '6' and '16'
# classes '8' and '9'
# classes '8' and '10'
# classes '8' and '11'
# classes '8' and '12'
# classes '8' and '13'
# classes '8' and '14'
# classes '8' and '16'
# classes '9' and '10'
# classes '9' and '11'
# classes '9' and '12'
# classes '9' and '13'
# classes '9' and '14'
# classes '9' and '16'
# classes '10' and '11'
# classes '10' and '12'
# classes '10' and '13'
# classes '10' and '14'
# classes '10' and '16'
# classes '11' and '12'
# classes '11' and '13'
# classes '11' and '14'
# classes '11' and '16'
# classes '12' and '13'
# classes '12' and '14'
# classes '12' and '16'
# classes '13' and '14'
# classes '13' and '16'
# classes '14' and '16'
# [Parallel(n_jobs=12)]: Done   2 out of   2 | elapsed:   14.3s finished
#   Finished evaluations for outer fold 'LEUCEGENE'.
#              outer_fold inner_fold  class_0  class_1  \
# 0     BEATAML1.0-COHORT   AAML0531        0        1
# 1     BEATAML1.0-COHORT   AAML0531        0        2
# 2     BEATAML1.0-COHORT   AAML0531        0        3
# 3     BEATAML1.0-COHORT   AAML0531        0        4
# 4     BEATAML1.0-COHORT   AAML0531        0        5
# ...                 ...        ...      ...      ...
# 3723          LEUCEGENE  TCGA-LAML       12       14
# 3724          LEUCEGENE  TCGA-LAML       12       16
# 3725          LEUCEGENE  TCGA-LAML       13       14
# 3726          LEUCEGENE  TCGA-LAML       13       16
# 3727          LEUCEGENE  TCGA-LAML       14       16
#
#                                                  params  accuracy  f1_binary  \
# 0     {'C': 10, 'class_weight': 'balanced', 'gamma':...  0.764706   0.862069
# 1     {'C': 10, 'class_weight': 'balanced', 'gamma':...  0.902778   0.940171
# 2     {'C': 10, 'class_weight': 'balanced', 'gamma':...  0.993377   0.991150
# 3     {'C': 10, 'class_weight': 'balanced', 'gamma':...  0.949153   0.972973
# 4     {'C': 10, 'class_weight': 'balanced', 'gamma':...  0.916667   0.932203
# ...                                                 ...       ...        ...
# 3723  {'C': 10, 'class_weight': 'balanced', 'gamma':...  0.333333   0.500000
# 3724  {'C': 10, 'class_weight': 'balanced', 'gamma':...  0.750000   0.000000
# 3725  {'C': 10, 'class_weight': 'balanced', 'gamma':...  0.333333   0.500000
# 3726  {'C': 10, 'class_weight': 'balanced', 'gamma':...  1.000000   1.000000
# 3727  {'C': 10, 'class_weight': 'balanced', 'gamma':...  1.000000   1.000000
#
#            mcc     kappa
# 0     0.070430  0.068493
# 1     0.701590  0.683417
# 2     0.985959  0.985860
# 3     0.551366  0.544987
# 4     0.832030  0.824818
# ...        ...       ...
# 3723  0.000000  0.000000
# 3724  0.000000  0.000000
# 3725  0.000000  0.000000
# 3726  1.000000  1.000000
# 3727  1.000000  1.000000
#
# [3728 rows x 9 columns]

# %%
def process_cv_results(df, param_grid, label_mapping, score_col):
    #df = df.dropna()
    #  Extract param names and expand 'params'
    param_names = list(param_grid.keys())
    params_df = df['params'].apply(pd.Series)

    # Normalize None values for groupby
    for col in param_names:
        if col in params_df.columns:
            params_df[col] = params_df[col].apply(lambda x: 'none' if x is None else x)

    #Combine expanded params with original DataFrame
    df_with_params = pd.concat([df.drop(columns=['params']), params_df], axis=1)

    # Determine group-by strategy based on evaluation type
    if 'class' in df_with_params.columns:
        # OvR
        group_cols = param_names + ['class']
        summary = df_with_params.groupby(group_cols)[score_col].mean().reset_index()
        best = summary.loc[summary.groupby('class')[score_col].idxmax()].reset_index(drop=True)

    elif 'class_0' in df_with_params.columns and 'class_1' in df_with_params.columns:
        # OvO
        group_cols = param_names + ['class_0', 'class_1']
        summary = df_with_params.groupby(group_cols)[score_col].mean().reset_index()
        best = summary.loc[summary.groupby(['class_0', 'class_1'])[score_col].idxmax()].reset_index(drop=True)

    else:
        # Standard multiclass
        group_cols = param_names
        summary = df_with_params.groupby(group_cols)[score_col].mean().reset_index()
        best = summary.loc[[summary[score_col].idxmax()]].reset_index(drop=True)

    int_to_label = {v: k for k, v in label_mapping.items()}
    if 'class' in best.columns:
        # OvR case
        best['class_label'] = best['class'].map(int_to_label)
        return best

    elif 'class_0' in best.columns and 'class_1' in best.columns:
        # OvO case
        best['class_0_label'] = best['class_0'].map(int_to_label)
        best['class_1_label'] = best['class_1'].map(int_to_label)
        return best

    else:
        return best

best_per_class_df = process_cv_results(
    df_parallel_results_study_as_fold,
    param_grid=param_grid,
    label_mapping = label_mapping,
    score_col = "kappa" # Kappa is best
)
best_per_class_df # np.float64(0.5714442426161126)
# Out:
#      n_genes   C  gamma kernel class_weight  probability  class_0  class_1  \
# 0       1000  10   auto    rbf     balanced         True        0        1
# 1       1000  10   auto    rbf     balanced         True        0        2
# 2       1000  10  0.001    rbf     balanced         True        0        3
# 3       1000  10   auto    rbf     balanced         True        0        4
# 4       1000  10  0.001    rbf     balanced         True        0        5
# ..       ...  ..    ...    ...          ...          ...      ...      ...
# 115     1000  10  0.001    rbf     balanced         True       12       14
# 116     1000  10  0.001    rbf     balanced         True       12       16
# 117     1000  10  0.001    rbf     balanced         True       13       14
# 118     1000  10  0.001    rbf     balanced         True       13       16
# 119     1000  10  0.001    rbf     balanced         True       14       16
#
#      f1_binary                                   class_0_label  \
# 0     0.591809  AML with MDS-related cytogenetic abnormalities
# 1     0.926166  AML with MDS-related cytogenetic abnormalities
# 2     0.989353  AML with MDS-related cytogenetic abnormalities
# 3     0.962595  AML with MDS-related cytogenetic abnormalities
# 4     0.908827  AML with MDS-related cytogenetic abnormalities
# ..         ...                                             ...
# 115   0.675564                                    KMT2A::MLLT1
# 116   0.616742                                    KMT2A::MLLT1
# 117   0.760813                                   KMT2A::MLLT10
# 118   0.986519                                   KMT2A::MLLT10
# 119   0.978218                           KMT2A::MLLT4 (::AFDN)
#
#                              class_1_label
# 0      AML with MDS-related gene mutations
# 1             AML with in-frame bZIP CEBPA
# 2    AML with inv(16)/t(16;16)/CBFB::MYH11
# 3       AML with inv(3)/t(3;3)/GATA2;MECOM
# 4                    AML with mutated NPM1
# ..                                     ...
# 115                  KMT2A::MLLT4 (::AFDN)
# 116                            NUP98::NSD1
# 117                  KMT2A::MLLT4 (::AFDN)
# 118                            NUP98::NSD1
# 119                            NUP98::NSD1
#
# [120 rows x 11 columns]

# %%
for outer_fold in (0,1):
    df2 = df_parallel_results[df_parallel_results['outer_fold'] == outer_fold]
    print(process_cv_results(
        df2,
        param_grid=param_grid,
        label_mapping = label_mapping,
        score_col = "kappa"
    ))
# Out:
#    n_genes  class_weight  max_depth     kappa
# 0     1000          True          5  0.717737
#    n_genes  class_weight  max_depth     kappa
# 0     1000          True          2  0.715102

# %%
type_eval = "OvO"
columns_to_drop = ["f1_macro","f1_binary", "class_label", "class_0_label", "class_1_label", "kappa", "mcc", "accuracy"]
columns_to_drop_existing = [col for col in columns_to_drop if col in best_per_class_df.columns]

per_class_results = []
overall_results = []

int_to_label = {v: k for k, v in label_mapping.items()}

for outer_fold, (train_idx, test_idx) in enumerate(outer_cv.split(X, y)):

    X_train_outer, X_test_outer = X[train_idx], X[test_idx]
    y_train_outer, y_test_outer = y[train_idx], y[test_idx]
    study_labels_outer = study_labels[train_idx]

    classes_in_fold = np.unique(y_train_outer)
    
    def pre_process_data(df, pipe):
        processed_X = {}
        for n_genes_i in list(set(df["n_genes"])):
            pipe_outer = clone(pipe)    
            X_train_n_genes = pipe_outer.fit_transform(X_train_outer, 
                                                    feature_selection__study_per_patient=study_labels_outer, 
                                                    feature_selection__n_genes=n_genes_i)
            X_test_n_genes = pipe_outer.transform(X_test_outer)
            processed_X[n_genes_i] = [X_train_n_genes, X_test_n_genes]
        return processed_X
    
    processed_X = pre_process_data(best_per_class_df, pipe)
    results_per_class = []

    df_outer_fold_results = df_parallel_results[df_parallel_results['outer_fold'] == outer_fold].copy()

    # Find the best parameters based ONLY on this outer fold's inner results
    best_params_for_outer_fold = process_cv_results(
        df_outer_fold_results,
        param_grid=param_grid,
        label_mapping=label_mapping,
        score_col='kappa' 
    )

    def standard_eval():
        df = best_params_for_outer_fold
        df = df.drop(columns=columns_to_drop_existing)
        params = params.iloc[0].to_dict()

        n_genes = params.pop('n_genes')
        X_train_n_genes = processed_X[n_genes][0]
        X_test_n_genes = processed_X[n_genes][1]

        y_train_outer = np.array(y_train_outer, dtype=np.int32)
        y_test_outer = np.array(y_test_outer, dtype=np.int32)

        clf = clone(model(**params))
        clf.fit(X_train_n_genes, y_train_outer)
        preds = clf.predict(X_test_n_genes)
        #preds = preds[:, 1]
        #preds = (preds >= 0.5).astype(int)
        results_per_class = {}
        results_overall = {
            'outer_fold': outer_fold,
            'accuracy': accuracy_score(y_test_outer, preds),
            'f1_macro': f1_score(y_test_outer, preds, average='macro'),
            'mcc': matthews_corrcoef(y_test_outer, preds),
            'kappa': cohen_kappa_score(y_test_outer, preds)
        }
        return results_overall, results_per_class

    def ovr_eval():
        df = best_params_for_outer_fold
        df = df.drop(columns=columns_to_drop_existing)
        df = df[df['class'].isin(classes_in_fold)]

        prob_df = pd.DataFrame(index = test_idx, columns = classes_in_fold)

        for cl in classes_in_fold:        
            params = df[df["class"] == cl]
            params = params.iloc[0].to_dict()

            n_genes = params.pop('n_genes')
            params.pop('class', None)

            X_train_n_genes = processed_X[n_genes][0]
            X_test_n_genes = processed_X[n_genes][1]

            if params["class_weight"]=='none':
                params.pop('class_weight')
                
            clf = clone(model(**params))
            params['n_genes'] = n_genes

            y_train_bin = [1 if yy == cl else 0 for yy in y_train_outer]
            y_test_bin = [1 if yy == cl else 0 for yy in y_test_outer]

            y_train_bin = np.array(y_train_bin, dtype=np.int32)
            y_test_bin = np.array(y_test_bin, dtype=np.int32)

            clf.fit(X_train_n_genes, y_train_bin)

            preds_proba = clf.predict_proba(X_test_n_genes)[:, 1]
            preds = (preds_proba >= 0.5).astype(int)
            results_per_class.append({
                'outer_fold': outer_fold,
                'class': cl,
                'accuracy': accuracy_score(y_test_bin, preds),
                'f1_binary': f1_score(y_test_bin, preds, average='binary', pos_label=1),
                'mcc': matthews_corrcoef(y_test_bin, preds),
                'kappa': cohen_kappa_score(y_test_bin, preds)
            })
            prob_df[cl] = preds_proba

        results_overall = {
            'outer_fold': outer_fold,
            'accuracy': accuracy_score(y_test_outer, prob_df.idxmax(axis=1)),
            'f1_macro': f1_score(y_test_outer, prob_df.idxmax(axis=1), average='macro'),
            'mcc': matthews_corrcoef(y_test_outer, prob_df.idxmax(axis=1)),
            'kappa': cohen_kappa_score(y_test_outer, prob_df.idxmax(axis=1))
        }
        return results_overall, results_per_class

    def ovo_eval():
        df = best_params_for_outer_fold
        df = df.drop(columns=columns_to_drop_existing)
        df = df[(df['class_0'].isin(classes_in_fold)) & (df['class_1'].isin(classes_in_fold))]

        results_per_class = []
        
        # Voting
        prob_df = pd.DataFrame(0, index = test_idx, columns = classes_in_fold)
        
        for index, df_row in df.iterrows():
            i = df_row["class_0"]
            j = df_row["class_1"]

            params = df_row.to_dict()

            n_genes = params.pop('n_genes')
            params.pop('class_0', None)
            params.pop('class_1', None)

            X_train_n_genes, X_test_n_genes = processed_X[n_genes]

            train_mask = [(yy == i or yy == j) for yy in y_train_outer]
            val_mask = [(yy == i or yy == j) for yy in y_test_outer]

            X_train_ij = X_train_n_genes[train_mask]
            y_train_ij = np.array([yy for yy in y_train_outer if yy == i or yy == j], dtype=np.int32) 
            y_train_ij = (y_train_ij == i).astype(np.int32) # label '1' for class i, and '0' for class j

            X_val_ij = X_test_n_genes[val_mask]
            y_val_ij = np.array([yy for yy in y_test_outer if yy == i or yy == j], dtype=np.int32) 
            y_val_ij = (y_val_ij == i).astype(np.int32) # label '1' for class i, and '0' for class j
            
            if params["class_weight"]=='none':
                params.pop('class_weight')

            clf = clone(model(**params))
            
            clf.fit(X_train_ij, y_train_ij)
            
            preds = clf.predict_proba(X_val_ij)
            preds = preds[:, 1]
            preds = (preds >= 0.5).astype(int)

            results_per_class.append({
                'outer_fold': outer_fold,
                'class_0': i,
                'class_1': j,
                'f1_binary': f1_score(y_val_ij, preds, average='binary', pos_label=1),
                'mcc': matthews_corrcoef(y_val_ij, preds),
                'kappa': cohen_kappa_score(y_val_ij, preds)
            })

            preds_all_test_orig = clf.predict_proba(X_test_n_genes)
            preds_all_test_orig = preds_all_test_orig[:, 1]
            preds_all_test = (preds_all_test_orig >= 0.5).astype(int)

            for prediction_idx, prediction in enumerate(preds_all_test):
                if prediction == 1:
                    prob_df.loc[test_idx[prediction_idx], i] += 1
                else:
                    prob_df.loc[test_idx[prediction_idx], j] += 1

        # votes
        preds_all = prob_df.idxmax(axis=1)

        results_overall = {
            'outer_fold': outer_fold,
            #'accuracy': accuracy_score(y_test_outer, preds_all),
            #'f1_macro': f1_score(y_test_outer, preds_all, average='macro'),
            'mcc votes': matthews_corrcoef(y_test_outer, preds_all),
            'kappa votes': cohen_kappa_score(y_test_outer, preds_all)
        }
        return results_overall, results_per_class

    # Dispatch table for clean logic
    eval_dispatch = {
        'OvR': ovr_eval,
        'OvO': ovo_eval
    }

    if type_eval not in eval_dispatch:
        raise ValueError(f"Unsupported evaluation type: {type}")
    
    results_overall, results_per_class = eval_dispatch[type_eval]()
    per_class_results.append(results_per_class)
    print(results_overall)
    overall_results.append(results_overall)
# Out:
# {'outer_fold': 0, 'mcc votes': np.float64(0.8450958861113496), 'kappa votes': np.float64(0.8447055763390022)}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 29
#      26         processed_X[n_genes_i] = [X_train_n_genes, X_test_n_genes]
#      27     return processed_X
# ---> 29 processed_X = pre_process_data(best_per_class_df, pipe)
#      30 results_per_class = []
#      32 df_outer_fold_results = df_parallel_results[df_parallel_results['outer_fold'] == outer_fold].copy()
#
# Cell In[14], line 22, in pre_process_data(df, pipe)
#      20 for n_genes_i in list(set(df["n_genes"])):
#      21     pipe_outer = clone(pipe)
# ---> 22     X_train_n_genes = pipe_outer.fit_transform(X_train_outer,
#      23                                             feature_selection__study_per_patient=study_labels_outer,
#      24                                             feature_selection__n_genes=n_genes_i)
#      25     X_test_n_genes = pipe_outer.transform(X_test_outer)
#      26     processed_X[n_genes_i] = [X_train_n_genes, X_test_n_genes]
#
# File ~/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:718, in Pipeline.fit_transform(self, X, y, **params)
#     679 """Fit the model and transform with the final estimator.
#     680
#     681 Fit all the transformers one after the other and sequentially transform
#    (...)    715     Transformed samples.
#     716 """
#     717 routed_params = self._check_method_params(method="fit_transform", props=params)
# --> 718 Xt = self._fit(X, y, routed_params)
#     720 last_step = self._final_estimator
#     721 with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#
# File ~/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:588, in Pipeline._fit(self, X, y, routed_params, raw_params)
#     581 # Fit or load from cache the current transformer
#     582 step_params = self._get_metadata_for_step(
#     583     step_idx=step_idx,
#     584     step_params=routed_params[name],
#     585     all_params=raw_params,
#     586 )
# --> 588 X, fitted_transformer = fit_transform_one_cached(
#     589     cloned_transformer,
#     590     X,
#     591     y,
#     592     weight=None,
#     593     message_clsname="Pipeline",
#     594     message=self._log_message(step_idx),
#     595     params=step_params,
#     596 )
#     597 # Replace the transformer of the step with the fitted
#     598 # transformer. This is necessary when loading the transformer
#     599 # from the cache.
#     600 self.steps[step_idx] = (name, fitted_transformer)
#
# File ~/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/joblib/memory.py:312, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     311 def __call__(self, *args, **kwargs):
# --> 312     return self.func(*args, **kwargs)
#
# File ~/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/sklearn/pipeline.py:1551, in _fit_transform_one(transformer, X, y, weight, message_clsname, message, params)
#    1549 with _print_elapsed_time(message_clsname, message):
#    1550     if hasattr(transformer, "fit_transform"):
# -> 1551         res = transformer.fit_transform(X, y, **params.get("fit_transform", {}))
#    1552     else:
#    1553         res = transformer.fit(X, y, **params.get("fit", {})).transform(
#    1554             X, **params.get("transform", {})
#    1555         )
#
# File ~/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/sklearn/utils/_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File ~/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/sklearn/base.py:918, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     903         warnings.warn(
#     904             (
#     905                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    913             UserWarning,
#     914         )
#     916 if y is None:
#     917     # fit method of arity 1 (unsupervised transformation)
# --> 918     return self.fit(X, **fit_params).transform(X)
#     919 else:
#     920     # fit method of arity 2 (supervised transformation)
#     921     return self.fit(X, y, **fit_params).transform(X)
#
# File ~/Documents/Leukem.ai/python_predict/transformers.py:145, in FeatureSelection.fit(self, X, y, study_per_patient, n_genes)
#     143         continue
#     144     X_study_arr = X[mask, :]
# --> 145     top_genes_by_study[study] = self._compute_top_genes(X_study_arr)
#     147 # Compute the intersection of top genes and preserve the original order.
#     148 intersect_genes = set.intersection(*top_genes_by_study.values())
#
# File ~/Documents/Leukem.ai/python_predict/transformers.py:116, in FeatureSelection._compute_top_genes(self, X_arr)
#     114 def _compute_top_genes(self, X_arr):
#     115     # Compute the median for each gene.
# --> 116     medians = np.median(X_arr, axis=0)
#     117     # Compute the MAD: median of absolute deviations.
#     118     mad = np.median(np.abs(X_arr - medians), axis=0)
#
# File ~/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3876, in median(a, axis, out, overwrite_input, keepdims)
#    3786 @array_function_dispatch(_median_dispatcher)
#    3787 def median(a, axis=None, out=None, overwrite_input=False, keepdims=False):
#    3788     """
#    3789     Compute the median along the specified axis.
#    3790
#    (...)   3874
#    3875     """
# -> 3876     return _ureduce(a, func=_median, keepdims=keepdims, axis=axis, out=out,
#    3877                     overwrite_input=overwrite_input)
#
# File ~/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3764, in _ureduce(a, func, keepdims, **kwargs)
#    3761             index_out = (0, ) * nd
#    3762             kwargs['out'] = out[(Ellipsis, ) + index_out]
# -> 3764 r = func(a, **kwargs)
#    3766 if out is not None:
#    3767     return out
#
# File ~/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:3909, in _median(a, axis, out, overwrite_input)
#    3907         part = a
#    3908 else:
# -> 3909     part = partition(a, kth, axis=axis)
#    3911 if part.shape == ():
#    3912     # make 0-D arrays work
#    3913     return part.item()
#
# File ~/Documents/Leukem.ai/.venv/lib/python3.12/site-packages/numpy/_core/fromnumeric.py:819, in partition(a, kth, axis, kind, order)
#     817     axis = -1
#     818 else:
# --> 819     a = asanyarray(a).copy(order="K")
#     820 a.partition(kth, axis=axis, kind=kind, order=order)
#     821 return a
#
# KeyboardInterrupt:

# %%
# OvO: {'outer_fold': 0, 'mcc votes': np.float64(0.8450958861113496), 'kappa votes': np.float64(0.8447055763390022)}

# %%
per_class_results[0]
# Out:
# [{'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 1,
#   'f1_binary': 0.9158878504672897,
#   'mcc': np.float64(0.8066855435212543),
#   'kappa': np.float64(0.8049792531120332)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 2,
#   'f1_binary': 0.9636363636363636,
#   'mcc': np.float64(0.7414141414141414),
#   'kappa': np.float64(0.7414141414141414)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 3,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 4,
#   'f1_binary': 0.9818181818181818,
#   'mcc': np.float64(0.7318181818181818),
#   'kappa': np.float64(0.7318181818181818)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 5,
#   'f1_binary': 0.9557522123893806,
#   'mcc': np.float64(0.9163448298943221),
#   'kappa': np.float64(0.915156744319816)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 6,
#   'f1_binary': 0.9345794392523364,
#   'mcc': np.float64(0.7504283707412239),
#   'kappa': np.float64(0.7459677419354839)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 7,
#   'f1_binary': 0.990990990990991,
#   'mcc': np.float64(0.917516612761795),
#   'kappa': np.float64(0.9141274238227147)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 8,
#   'f1_binary': 0.972972972972973,
#   'mcc': np.float64(0.943443729531313),
#   'kappa': np.float64(0.9432750624331074)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 9,
#   'f1_binary': 0.9345794392523364,
#   'mcc': np.float64(0.8225225129453326),
#   'kappa': np.float64(0.8200734394124847)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 10,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 11,
#   'f1_binary': 0.9734513274336283,
#   'mcc': np.float64(0.7698522025642995),
#   'kappa': np.float64(0.7442489851150202)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 12,
#   'f1_binary': 0.9734513274336283,
#   'mcc': np.float64(0.6158817620514396),
#   'kappa': np.float64(0.5499999999999999)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 13,
#   'f1_binary': 0.9532710280373832,
#   'mcc': np.float64(0.7624425757515653),
#   'kappa': np.float64(0.7540983606557377)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 14,
#   'f1_binary': 0.9908256880733946,
#   'mcc': np.float64(0.917364944587726),
#   'kappa': np.float64(0.9139633286318759)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 15,
#   'f1_binary': 0.9821428571428571,
#   'mcc': np.float64(0.5671308728156005),
#   'kappa': np.float64(0.48672566371681414)},
#  {'outer_fold': 0,
#   'class_0': 0,
#   'class_1': 16,
#   'f1_binary': 0.9649122807017544,
#   'mcc': np.float64(0.7478783550139054),
#   'kappa': np.float64(0.717391304347826)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 2,
#   'f1_binary': 0.9620253164556962,
#   'mcc': np.float64(0.7877263614433762),
#   'kappa': np.float64(0.7857142857142857)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 3,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 4,
#   'f1_binary': 0.975,
#   'mcc': np.float64(0.6896446592974972),
#   'kappa': np.float64(0.6446280991735538)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 5,
#   'f1_binary': 0.975,
#   'mcc': np.float64(0.959698946213619),
#   'kappa': np.float64(0.9588875453446191)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 6,
#   'f1_binary': 0.975,
#   'mcc': np.float64(0.9161393640106364),
#   'kappa': np.float64(0.9126365054602184)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 7,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 8,
#   'f1_binary': 0.9873417721518988,
#   'mcc': np.float64(0.9776923610938035),
#   'kappa': np.float64(0.9774436090225564)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 9,
#   'f1_binary': 0.961038961038961,
#   'mcc': np.float64(0.9106192160459141),
#   'kappa': np.float64(0.9102112676056338)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 10,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 11,
#   'f1_binary': 0.9873417721518988,
#   'mcc': np.float64(0.9236476600955582),
#   'kappa': np.float64(0.9207419898819562)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 12,
#   'f1_binary': 0.9620253164556962,
#   'mcc': np.float64(0.6340751391209737),
#   'kappa': np.float64(0.6292134831460674)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 13,
#   'f1_binary': 0.987012987012987,
#   'mcc': np.float64(0.9450726919990827),
#   'kappa': np.float64(0.9435665914221218)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 14,
#   'f1_binary': 0.987012987012987,
#   'mcc': np.float64(0.9138735334633754),
#   'kappa': np.float64(0.9101796407185628)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 1,
#   'class_1': 16,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 3,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 4,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 5,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 6,
#   'f1_binary': 0.9411764705882353,
#   'mcc': np.float64(0.9162456945817024),
#   'kappa': np.float64(0.912751677852349)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 7,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 8,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 9,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 10,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 11,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 12,
#   'f1_binary': 0.9473684210526315,
#   'mcc': np.float64(0.848528137423857),
#   'kappa': np.float64(0.8372093023255814)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 13,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 14,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 2,
#   'class_1': 16,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 4,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 5,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 6,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 7,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 8,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 9,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 10,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 11,
#   'f1_binary': 0.9906542056074766,
#   'mcc': np.float64(0.9267126287562376),
#   'kappa': np.float64(0.9240348692403487)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 12,
#   'f1_binary': 0.9814814814814815,
#   'mcc': np.float64(0.7603826787755086),
#   'kappa': np.float64(0.7327188940092166)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 13,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 14,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 3,
#   'class_1': 16,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 4,
#   'class_1': 5,
#   'f1_binary': 0.8888888888888888,
#   'mcc': np.float64(0.8873001675315898),
#   'kappa': np.float64(0.8809946714031972)},
#  {'outer_fold': 0,
#   'class_0': 4,
#   'class_1': 6,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 4,
#   'class_1': 7,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 4,
#   'class_1': 8,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 4,
#   'class_1': 9,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 4,
#   'class_1': 10,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 4,
#   'class_1': 11,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 4,
#   'class_1': 12,
#   'f1_binary': 0.8888888888888888,
#   'mcc': np.float64(0.8),
#   'kappa': np.float64(0.7804878048780488)},
#  {'outer_fold': 0,
#   'class_0': 4,
#   'class_1': 13,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 4,
#   'class_1': 14,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 4,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 4,
#   'class_1': 16,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 5,
#   'class_1': 6,
#   'f1_binary': 0.9838709677419355,
#   'mcc': np.float64(0.9307698415351914),
#   'kappa': np.float64(0.928379588182632)},
#  {'outer_fold': 0,
#   'class_0': 5,
#   'class_1': 7,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 5,
#   'class_1': 8,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 5,
#   'class_1': 9,
#   'f1_binary': 0.992,
#   'mcc': np.float64(0.9753577555557507),
#   'kappa': np.float64(0.9750542299349241)},
#  {'outer_fold': 0,
#   'class_0': 5,
#   'class_1': 10,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 5,
#   'class_1': 11,
#   'f1_binary': 0.9841269841269841,
#   'mcc': np.float64(0.8591269841269841),
#   'kappa': np.float64(0.8591269841269842)},
#  {'outer_fold': 0,
#   'class_0': 5,
#   'class_1': 12,
#   'f1_binary': 0.9763779527559056,
#   'mcc': np.float64(0.6479515952918626),
#   'kappa': np.float64(0.6433566433566433)},
#  {'outer_fold': 0,
#   'class_0': 5,
#   'class_1': 13,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 5,
#   'class_1': 14,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 5,
#   'class_1': 15,
#   'f1_binary': 0.9838709677419355,
#   'mcc': np.float64(0.7622023228463561),
#   'kappa': np.float64(0.7349397590361446)},
#  {'outer_fold': 0,
#   'class_0': 5,
#   'class_1': 16,
#   'f1_binary': 0.9841269841269841,
#   'mcc': np.float64(0.8841269841269841),
#   'kappa': np.float64(0.8841269841269841)},
#  {'outer_fold': 0,
#   'class_0': 6,
#   'class_1': 7,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 6,
#   'class_1': 8,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 6,
#   'class_1': 9,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 6,
#   'class_1': 10,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 6,
#   'class_1': 11,
#   'f1_binary': 0.9714285714285714,
#   'mcc': np.float64(0.9090593428863095),
#   'kappa': np.float64(0.9049429657794676)},
#  {'outer_fold': 0,
#   'class_0': 6,
#   'class_1': 12,
#   'f1_binary': 0.9444444444444444,
#   'mcc': np.float64(0.7326950970650465),
#   'kappa': np.float64(0.6986301369863014)},
#  {'outer_fold': 0,
#   'class_0': 6,
#   'class_1': 13,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 6,
#   'class_1': 14,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 6,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 6,
#   'class_1': 16,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 7,
#   'class_1': 8,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 7,
#   'class_1': 9,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 7,
#   'class_1': 10,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 7,
#   'class_1': 11,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 7,
#   'class_1': 12,
#   'f1_binary': 0.9333333333333333,
#   'mcc': np.float64(0.8366600265340756),
#   'kappa': np.float64(0.8235294117647058)},
#  {'outer_fold': 0,
#   'class_0': 7,
#   'class_1': 13,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 7,
#   'class_1': 14,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 7,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 7,
#   'class_1': 16,
#   'f1_binary': 0.9230769230769231,
#   'mcc': np.float64(0.8827348295047495),
#   'kappa': np.float64(0.8759124087591241)},
#  {'outer_fold': 0,
#   'class_0': 8,
#   'class_1': 9,
#   'f1_binary': 0.9900990099009901,
#   'mcc': np.float64(0.973505222533836),
#   'kappa': np.float64(0.9731543624161074)},
#  {'outer_fold': 0,
#   'class_0': 8,
#   'class_1': 10,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 8,
#   'class_1': 11,
#   'f1_binary': 0.9902912621359223,
#   'mcc': np.float64(0.9263763149622711),
#   'kappa': np.float64(0.9236739974126779)},
#  {'outer_fold': 0,
#   'class_0': 8,
#   'class_1': 12,
#   'f1_binary': 0.9902912621359223,
#   'mcc': np.float64(0.8857851797221404),
#   'kappa': np.float64(0.8793103448275862)},
#  {'outer_fold': 0,
#   'class_0': 8,
#   'class_1': 13,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 8,
#   'class_1': 14,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 8,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 8,
#   'class_1': 16,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 9,
#   'class_1': 10,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 9,
#   'class_1': 11,
#   'f1_binary': 0.9666666666666667,
#   'mcc': np.float64(0.8376233659741151),
#   'kappa': np.float64(0.8246445497630331)},
#  {'outer_fold': 0,
#   'class_0': 9,
#   'class_1': 12,
#   'f1_binary': 0.9508196721311475,
#   'mcc': np.float64(0.6020797289396148),
#   'kappa': np.float64(0.5321100917431193)},
#  {'outer_fold': 0,
#   'class_0': 9,
#   'class_1': 13,
#   'f1_binary': 0.9491525423728814,
#   'mcc': np.float64(0.8081352297940448),
#   'kappa': np.float64(0.8064516129032258)},
#  {'outer_fold': 0,
#   'class_0': 9,
#   'class_1': 14,
#   'f1_binary': 0.9830508474576272,
#   'mcc': np.float64(0.8975274678557507),
#   'kappa': np.float64(0.8923076923076924)},
#  {'outer_fold': 0,
#   'class_0': 9,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 9,
#   'class_1': 16,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 10,
#   'class_1': 11,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 10,
#   'class_1': 12,
#   'f1_binary': 0.9629629629629629,
#   'mcc': np.float64(0.8618916073713346),
#   'kappa': np.float64(0.8524590163934427)},
#  {'outer_fold': 0,
#   'class_0': 10,
#   'class_1': 13,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 10,
#   'class_1': 14,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 10,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 10,
#   'class_1': 16,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 11,
#   'class_1': 12,
#   'f1_binary': 0.8888888888888888,
#   'mcc': np.float64(0.6928203230275508),
#   'kappa': np.float64(0.6486486486486487)},
#  {'outer_fold': 0,
#   'class_0': 11,
#   'class_1': 13,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 11,
#   'class_1': 14,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 11,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 11,
#   'class_1': 16,
#   'f1_binary': 0.9333333333333333,
#   'mcc': np.float64(0.8918825850158447),
#   'kappa': np.float64(0.8860759493670887)},
#  {'outer_fold': 0,
#   'class_0': 12,
#   'class_1': 13,
#   'f1_binary': 0.8,
#   'mcc': np.float64(0.7090909090909091),
#   'kappa': np.float64(0.7090909090909091)},
#  {'outer_fold': 0,
#   'class_0': 12,
#   'class_1': 14,
#   'f1_binary': 0.8888888888888888,
#   'mcc': np.float64(0.8280786712108251),
#   'kappa': np.float64(0.8135593220338984)},
#  {'outer_fold': 0,
#   'class_0': 12,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 12,
#   'class_1': 16,
#   'f1_binary': 0.75,
#   'mcc': np.float64(0.7071067811865475),
#   'kappa': np.float64(0.6666666666666667)},
#  {'outer_fold': 0,
#   'class_0': 13,
#   'class_1': 14,
#   'f1_binary': 0.9565217391304348,
#   'mcc': np.float64(0.8740073734751262),
#   'kappa': np.float64(0.8661417322834646)},
#  {'outer_fold': 0,
#   'class_0': 13,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 13,
#   'class_1': 16,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 14,
#   'class_1': 15,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 14,
#   'class_1': 16,
#   'f1_binary': 1.0,
#   'mcc': np.float64(1.0),
#   'kappa': np.float64(1.0)},
#  {'outer_fold': 0,
#   'class_0': 15,
#   'class_1': 16,
#   'f1_binary': 0.75,
#   'mcc': np.float64(0.6928203230275508),
#   'kappa': np.float64(0.6486486486486487)}]

# %%
len(np.unique(y)) * (len(np.unique(y))-1) / 2
# Out:
# 136.0
